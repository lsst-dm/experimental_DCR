# %%
import numpy as np
from python.notebook_utils import look
from python.simulation_utils import simulation_wrapper, OpSim_wrapper

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import lsst.afw.display.rgb as rgb

# %% [markdown]
# Load the 2018 baseline survey

# %%
n_obs_list = [5, 8, 10]
repeat_obs = 3  # number of different fields with the given n_obs to generate simulations of
template_year = 1 
alert_year = 2
n_star = 10000
n_quasar = 1000

# %% [markdown]
# Connect to the database and set up for all of the simulations

# %% [markdown]
# Create a second set of simulations where the fields can be mosaiced together

# %%
airmass_threshold = 1.15  # Target fields must include at least one observation above this airmass to be included
opsim = OpSim_wrapper(year=template_year, filt='g', opsim_db='/Users/sullivan/LSST/OpSim/baseline2018a.db',
                      sim_directory="/Users/sullivan/LSST/simulations/OpSim/pontus_2568/",
                      conditions_db="/Users/sullivan/LSST/OpSim/pontus_2568.db",
                      airmass_threshold=airmass_threshold)

# %%
nx = repeat_obs
ny = len(n_obs_list)
n = nx if nx > ny else ny
simulation_size = n
dither_scale = 0.95
dither_x = dither_scale*(np.arange(nx) - (nx - 1)/2)
dither_y = dither_scale*(np.arange(ny) - (ny - 1)/2)

# %%
initial_const = True
initial_var = True
seed = 8
randomize_conditions = True
for d_y, n_obs in zip(dither_y, n_obs_list):
    rng = np.random.RandomState(n_obs + 2)
    for rpt in range(repeat_obs):
        d_x = dither_x[rpt]
        index = int(np.rint(rng.rand()*1000))
        opsim.set_field(n_obs=n_obs, index=index, year=template_year)
        sim = opsim.initialize_simulation(n_star=n_star*n**2, n_quasar=n_quasar*n**2,
                                          dither=(d_x, d_y), seed=seed,
                                          simulation_size=simulation_size)
        opsim.run_simulation(sim, use_seeing=False, write_catalog=True,
                             initialize_directory=initial_const, mosaic=True)
        opsim.run_simulation(sim, use_seeing=True, write_catalog=False,
                             initialize_directory=initial_var, mosaic=True)
        initial_const = False
        initial_var = False
        
        opsim.update_year(alert_year, randomize_conditions=randomize_conditions)
        opsim.run_simulation(sim, use_seeing=False, write_catalog=False, initialize_directory=False, mosaic=True)
        opsim.run_simulation(sim, use_seeing=True, write_catalog=False, initialize_directory=False, mosaic=True)
# Out:
# Selecting 10 obs from field 2682, with seeing range 0.541 to 0.815 and airmass range 1.158 to 1.209
# Number and flux contribution of stars of each type:
#  [M 69157| 1.73%] [K 10685| 2.16%] [G 6796| 3.86%] [F 2687| 4.59%] [A 564| 14.89%] [B 111| 72.77%] [O 0| 0.00%]
# Simulating 2624 stars within observable region
# Time to model 2613 stars: [13.062s | 0.00500s per star]
# Time to model 11 bright stars: [9.319s | 0.84718s per star]
# Simulating 243 quasars within observable region
# Time to model 242 stars: [2.412s | 0.00997s per star]
# Time to model 1 bright star: [7.574s]
# Writing 6267 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  6.2407183228272425 22.673530195451143
# FFT timing for 15 DCR planes: [2.612s | 0.174s per plane]
# FFT timing for 15 DCR planes: [6.765s | 0.451s per plane]
# FFT timing for 15 DCR planes: [1.873s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.421s | 0.495s per plane]
# FFT timing for 15 DCR planes: [1.775s | 0.118s per plane]
# FFT timing for 15 DCR planes: [6.959s | 0.464s per plane]
# FFT timing for 15 DCR planes: [1.709s | 0.114s per plane]
# FFT timing for 15 DCR planes: [6.899s | 0.460s per plane]
# FFT timing for 15 DCR planes: [1.640s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.977s | 0.465s per plane]
# FFT timing for 15 DCR planes: [2.187s | 0.146s per plane]
# FFT timing for 15 DCR planes: [7.292s | 0.486s per plane]
# FFT timing for 15 DCR planes: [1.584s | 0.106s per plane]
# FFT timing for 15 DCR planes: [7.683s | 0.512s per plane]
# FFT timing for 15 DCR planes: [2.115s | 0.141s per plane]
# FFT timing for 15 DCR planes: [6.663s | 0.444s per plane]
# FFT timing for 15 DCR planes: [1.606s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.666s | 0.444s per plane]
# FFT timing for 15 DCR planes: [1.597s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.654s | 0.444s per plane]
# FFT timing for 15 DCR planes: [2.479s | 0.165s per plane]
# FFT timing for 15 DCR planes: [6.639s | 0.443s per plane]
# FFT timing for 15 DCR planes: [1.694s | 0.113s per plane]
# FFT timing for 15 DCR planes: [6.680s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.821s | 0.121s per plane]
# FFT timing for 15 DCR planes: [6.641s | 0.443s per plane]
# FFT timing for 15 DCR planes: [1.812s | 0.121s per plane]
# FFT timing for 15 DCR planes: [6.661s | 0.444s per plane]
# FFT timing for 15 DCR planes: [1.598s | 0.107s per plane]
# FFT timing for 15 DCR planes: [8.972s | 0.598s per plane]
# FFT timing for 15 DCR planes: [1.614s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.749s | 0.450s per plane]
# FFT timing for 15 DCR planes: [1.593s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.687s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.628s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.656s | 0.444s per plane]
# FFT timing for 15 DCR planes: [1.620s | 0.108s per plane]
# FFT timing for 15 DCR planes: [7.284s | 0.486s per plane]
# FFT timing for 15 DCR planes: [1.690s | 0.113s per plane]
# FFT timing for 15 DCR planes: [6.967s | 0.464s per plane]
# Selecting 7 randomized obs from field 2682, with seeing range 0.675 to 1.210 and airmass range 1.007 to 1.207
# FFT timing for 15 DCR planes: [1.567s | 0.104s per plane]
# FFT timing for 15 DCR planes: [6.644s | 0.443s per plane]
# FFT timing for 15 DCR planes: [1.604s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.663s | 0.444s per plane]
# FFT timing for 15 DCR planes: [1.653s | 0.110s per plane]
# FFT timing for 15 DCR planes: [7.869s | 0.525s per plane]
# FFT timing for 15 DCR planes: [1.738s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.350s | 0.490s per plane]
# FFT timing for 15 DCR planes: [1.725s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.158s | 0.477s per plane]
# FFT timing for 15 DCR planes: [1.836s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.419s | 0.495s per plane]
# FFT timing for 15 DCR planes: [1.822s | 0.121s per plane]
# FFT timing for 15 DCR planes: [7.068s | 0.471s per plane]
# FFT timing for 15 DCR planes: [2.008s | 0.134s per plane]
# FFT timing for 15 DCR planes: [7.593s | 0.506s per plane]
# FFT timing for 15 DCR planes: [1.726s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.579s | 0.505s per plane]
# FFT timing for 15 DCR planes: [1.837s | 0.122s per plane]
# FFT timing for 15 DCR planes: [9.377s | 0.625s per plane]
# FFT timing for 15 DCR planes: [1.982s | 0.132s per plane]
# FFT timing for 15 DCR planes: [7.100s | 0.473s per plane]
# FFT timing for 15 DCR planes: [1.854s | 0.124s per plane]
# FFT timing for 15 DCR planes: [6.807s | 0.454s per plane]
# FFT timing for 15 DCR planes: [1.777s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.187s | 0.479s per plane]
# FFT timing for 15 DCR planes: [1.644s | 0.110s per plane]
# FFT timing for 15 DCR planes: [7.361s | 0.491s per plane]
# Selecting 8 obs from field 2725, with seeing range 0.699 to 1.011 and airmass range 1.167 to 1.250
# Number and flux contribution of stars of each type:
#  [M 69157| 1.73%] [K 10685| 2.16%] [G 6796| 3.86%] [F 2687| 4.59%] [A 564| 14.89%] [B 111| 72.77%] [O 0| 0.00%]
# Simulating 2496 stars within observable region
# Time to model 2485 stars: [11.427s | 0.00460s per star]
# Time to model 11 bright stars: [9.332s | 0.84834s per star]
# Simulating 268 quasars within observable region
# Time to model 267 stars: [2.525s | 0.00946s per star]
# Time to model 1 bright star: [8.125s]
# Writing 6267 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  6.2407183228272425 22.673530195451143
# FFT timing for 15 DCR planes: [1.778s | 0.119s per plane]
# FFT timing for 15 DCR planes: [6.813s | 0.454s per plane]
# FFT timing for 15 DCR planes: [1.613s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.651s | 0.443s per plane]
# FFT timing for 15 DCR planes: [1.598s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.622s | 0.441s per plane]
# FFT timing for 15 DCR planes: [1.613s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.681s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.602s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.685s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.598s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.685s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.591s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.632s | 0.442s per plane]
# FFT timing for 15 DCR planes: [1.608s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.616s | 0.441s per plane]
# FFT timing for 15 DCR planes: [1.637s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.637s | 0.442s per plane]
# FFT timing for 15 DCR planes: [1.806s | 0.120s per plane]
# FFT timing for 15 DCR planes: [6.692s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.602s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.687s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.609s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.693s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.793s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.460s | 0.497s per plane]
# FFT timing for 15 DCR planes: [1.783s | 0.119s per plane]
# FFT timing for 15 DCR planes: [6.700s | 0.447s per plane]
# FFT timing for 15 DCR planes: [1.602s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.699s | 0.447s per plane]
# FFT timing for 15 DCR planes: [1.604s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.694s | 0.446s per plane]
# Selecting 13 randomized obs from field 2725, with seeing range 0.523 to 0.956 and airmass range 1.024 to 1.156
# FFT timing for 15 DCR planes: [1.589s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.676s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.644s | 0.110s per plane]
# FFT timing for 15 DCR planes: [7.119s | 0.475s per plane]
# FFT timing for 15 DCR planes: [1.843s | 0.123s per plane]
# FFT timing for 15 DCR planes: [7.324s | 0.488s per plane]
# FFT timing for 15 DCR planes: [1.757s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.241s | 0.483s per plane]
# FFT timing for 15 DCR planes: [1.759s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.254s | 0.484s per plane]
# FFT timing for 15 DCR planes: [1.754s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.402s | 0.493s per plane]
# FFT timing for 15 DCR planes: [1.633s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.672s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.608s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.660s | 0.444s per plane]
# FFT timing for 15 DCR planes: [1.599s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.699s | 0.447s per plane]
# FFT timing for 15 DCR planes: [1.594s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.699s | 0.447s per plane]
# FFT timing for 15 DCR planes: [1.605s | 0.107s per plane]
# FFT timing for 15 DCR planes: [7.297s | 0.486s per plane]
# FFT timing for 15 DCR planes: [1.663s | 0.111s per plane]
# FFT timing for 15 DCR planes: [7.058s | 0.471s per plane]
# FFT timing for 15 DCR planes: [1.641s | 0.109s per plane]
# FFT timing for 15 DCR planes: [7.460s | 0.497s per plane]
# FFT timing for 15 DCR planes: [1.823s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.190s | 0.479s per plane]
# FFT timing for 15 DCR planes: [1.586s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.768s | 0.451s per plane]
# FFT timing for 15 DCR planes: [1.707s | 0.114s per plane]
# FFT timing for 15 DCR planes: [6.725s | 0.448s per plane]
# FFT timing for 15 DCR planes: [1.592s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.676s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.597s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.680s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.606s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.683s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.607s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.675s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.630s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.684s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.729s | 0.115s per plane]
# FFT timing for 15 DCR planes: [6.695s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.590s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.654s | 0.444s per plane]
# FFT timing for 15 DCR planes: [1.605s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.644s | 0.443s per plane]
# FFT timing for 15 DCR planes: [1.768s | 0.118s per plane]
# FFT timing for 15 DCR planes: [6.730s | 0.449s per plane]
# FFT timing for 15 DCR planes: [2.217s | 0.148s per plane]
# FFT timing for 15 DCR planes: [6.704s | 0.447s per plane]
# Selecting 6 obs from field 2874, with seeing range 0.575 to 0.759 and airmass range 1.204 to 1.271
# Number and flux contribution of stars of each type:
#  [M 69157| 1.73%] [K 10685| 2.16%] [G 6796| 3.86%] [F 2687| 4.59%] [A 564| 14.89%] [B 111| 72.77%] [O 0| 0.00%]
# Simulating 2532 stars within observable region
# Time to model 2522 stars: [11.262s | 0.00447s per star]
# Time to model 10 bright stars: [10.053s | 1.00527s per star]
# Simulating 265 quasars within observable region
# Time to model 264 stars: [3.086s | 0.01169s per star]
# Time to model 1 bright star: [7.520s]
# Writing 6267 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  6.2407183228272425 22.673530195451143
# FFT timing for 15 DCR planes: [1.818s | 0.121s per plane]
# FFT timing for 15 DCR planes: [6.802s | 0.453s per plane]
# FFT timing for 15 DCR planes: [1.601s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.681s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.610s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.693s | 0.446s per plane]
# FFT timing for 15 DCR planes: [1.599s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.674s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.590s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.674s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.596s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.664s | 0.444s per plane]
# FFT timing for 15 DCR planes: [1.581s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.606s | 0.440s per plane]
# FFT timing for 15 DCR planes: [1.632s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.644s | 0.443s per plane]
# FFT timing for 15 DCR planes: [1.875s | 0.125s per plane]
# FFT timing for 15 DCR planes: [8.175s | 0.545s per plane]
# FFT timing for 15 DCR planes: [1.629s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.677s | 0.445s per plane]
# FFT timing for 15 DCR planes: [2.356s | 0.157s per plane]
# FFT timing for 15 DCR planes: [7.758s | 0.517s per plane]
# FFT timing for 15 DCR planes: [1.860s | 0.124s per plane]
# FFT timing for 15 DCR planes: [6.865s | 0.458s per plane]
# Selecting 3 randomized obs from field 2874, with seeing range 0.745 to 1.422 and airmass range 1.034 to 1.879
# FFT timing for 15 DCR planes: [1.576s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.648s | 0.443s per plane]
# FFT timing for 15 DCR planes: [1.602s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.659s | 0.444s per plane]
# FFT timing for 15 DCR planes: [1.617s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.670s | 0.445s per plane]
# FFT timing for 15 DCR planes: [1.837s | 0.122s per plane]
# FFT timing for 15 DCR planes: [6.713s | 0.448s per plane]
# FFT timing for 15 DCR planes: [1.585s | 0.106s per plane]
# FFT timing for 15 DCR planes: [8.719s | 0.581s per plane]
# FFT timing for 15 DCR planes: [1.899s | 0.127s per plane]
# FFT timing for 15 DCR planes: [6.857s | 0.457s per plane]
# Selecting 12 obs from field 359, with seeing range 0.564 to 1.414 and airmass range 1.148 to 1.190
# Number and flux contribution of stars of each type:
#  [M 69157| 1.73%] [K 10685| 2.16%] [G 6796| 3.86%] [F 2687| 4.59%] [A 564| 14.89%] [B 111| 72.77%] [O 0| 0.00%]
# Simulating 2475 stars within observable region
# Time to model 2461 stars: [11.942s | 0.00485s per star]
# Time to model 14 bright stars: [12.306s | 0.87897s per star]
# Simulating 226 quasars within observable region
# Time to model 225 stars: [2.568s | 0.01141s per star]
# Time to model 1 bright star: [8.174s]
# Writing 6267 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  6.2407183228272425 22.673530195451143
# FFT timing for 15 DCR planes: [1.902s | 0.127s per plane]
# FFT timing for 15 DCR planes: [7.160s | 0.477s per plane]
# FFT timing for 15 DCR planes: [1.729s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.052s | 0.470s per plane]
# FFT timing for 15 DCR planes: [2.240s | 0.149s per plane]
# FFT timing for 15 DCR planes: [7.395s | 0.493s per plane]
# FFT timing for 15 DCR planes: [1.917s | 0.128s per plane]
# FFT timing for 15 DCR planes: [7.723s | 0.515s per plane]
# FFT timing for 15 DCR planes: [1.779s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.047s | 0.470s per plane]
# FFT timing for 15 DCR planes: [1.833s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.081s | 0.472s per plane]
# FFT timing for 15 DCR planes: [1.710s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.240s | 0.483s per plane]
# FFT timing for 15 DCR planes: [1.747s | 0.116s per plane]
# FFT timing for 15 DCR planes: [6.939s | 0.463s per plane]
# FFT timing for 15 DCR planes: [1.698s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.130s | 0.475s per plane]
# FFT timing for 15 DCR planes: [1.721s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.197s | 0.480s per plane]
# FFT timing for 15 DCR planes: [1.704s | 0.114s per plane]
# FFT timing for 15 DCR planes: [6.926s | 0.462s per plane]
# FFT timing for 15 DCR planes: [1.697s | 0.113s per plane]
# FFT timing for 15 DCR planes: [6.912s | 0.461s per plane]
# FFT timing for 15 DCR planes: [1.687s | 0.112s per plane]
# FFT timing for 15 DCR planes: [8.500s | 0.567s per plane]
# FFT timing for 15 DCR planes: [1.791s | 0.119s per plane]
# FFT timing for 15 DCR planes: [8.782s | 0.585s per plane]
# FFT timing for 15 DCR planes: [2.012s | 0.134s per plane]
# FFT timing for 15 DCR planes: [8.715s | 0.581s per plane]
# FFT timing for 15 DCR planes: [2.434s | 0.162s per plane]
# FFT timing for 15 DCR planes: [7.491s | 0.499s per plane]
# FFT timing for 15 DCR planes: [2.439s | 0.163s per plane]
# FFT timing for 15 DCR planes: [8.718s | 0.581s per plane]
# FFT timing for 15 DCR planes: [2.819s | 0.188s per plane]
# FFT timing for 15 DCR planes: [9.492s | 0.633s per plane]
# FFT timing for 15 DCR planes: [2.472s | 0.165s per plane]
# FFT timing for 15 DCR planes: [7.671s | 0.511s per plane]
# FFT timing for 15 DCR planes: [1.672s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.981s | 0.465s per plane]
# FFT timing for 15 DCR planes: [1.993s | 0.133s per plane]
# FFT timing for 15 DCR planes: [7.129s | 0.475s per plane]
# FFT timing for 15 DCR planes: [1.928s | 0.129s per plane]
# FFT timing for 15 DCR planes: [8.196s | 0.546s per plane]
# FFT timing for 15 DCR planes: [1.674s | 0.112s per plane]
# FFT timing for 15 DCR planes: [8.289s | 0.553s per plane]
# FFT timing for 15 DCR planes: [1.958s | 0.131s per plane]
# FFT timing for 15 DCR planes: [7.484s | 0.499s per plane]
# Selecting 12 randomized obs from field 359, with seeing range 0.694 to 0.984 and airmass range 1.010 to 1.195
# FFT timing for 15 DCR planes: [1.670s | 0.111s per plane]
# FFT timing for 15 DCR planes: [8.009s | 0.534s per plane]
# FFT timing for 15 DCR planes: [1.715s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.036s | 0.469s per plane]
# FFT timing for 15 DCR planes: [1.861s | 0.124s per plane]
# FFT timing for 15 DCR planes: [7.318s | 0.488s per plane]
# FFT timing for 15 DCR planes: [1.723s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.286s | 0.486s per plane]
# FFT timing for 15 DCR planes: [1.719s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.509s | 0.501s per plane]
# FFT timing for 15 DCR planes: [1.701s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.092s | 0.473s per plane]
# FFT timing for 15 DCR planes: [1.741s | 0.116s per plane]
# FFT timing for 15 DCR planes: [8.316s | 0.554s per plane]
# FFT timing for 15 DCR planes: [1.994s | 0.133s per plane]
# FFT timing for 15 DCR planes: [9.126s | 0.608s per plane]
# FFT timing for 15 DCR planes: [2.762s | 0.184s per plane]
# FFT timing for 15 DCR planes: [7.184s | 0.479s per plane]
# FFT timing for 15 DCR planes: [1.718s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.372s | 0.491s per plane]
# FFT timing for 15 DCR planes: [2.042s | 0.136s per plane]
# FFT timing for 15 DCR planes: [7.015s | 0.468s per plane]
# FFT timing for 15 DCR planes: [1.712s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.169s | 0.478s per plane]
# FFT timing for 15 DCR planes: [1.783s | 0.119s per plane]
# FFT timing for 15 DCR planes: [9.361s | 0.624s per plane]
# FFT timing for 15 DCR planes: [1.715s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.283s | 0.486s per plane]
# FFT timing for 15 DCR planes: [1.881s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.251s | 0.483s per plane]
# FFT timing for 15 DCR planes: [1.952s | 0.130s per plane]
# FFT timing for 15 DCR planes: [7.218s | 0.481s per plane]
# FFT timing for 15 DCR planes: [2.044s | 0.136s per plane]
# FFT timing for 15 DCR planes: [7.391s | 0.493s per plane]
# FFT timing for 15 DCR planes: [1.712s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.066s | 0.471s per plane]
# FFT timing for 15 DCR planes: [1.889s | 0.126s per plane]
# FFT timing for 15 DCR planes: [8.082s | 0.539s per plane]
# FFT timing for 15 DCR planes: [1.860s | 0.124s per plane]
# FFT timing for 15 DCR planes: [7.315s | 0.488s per plane]
# FFT timing for 15 DCR planes: [1.709s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.014s | 0.468s per plane]
# FFT timing for 15 DCR planes: [1.712s | 0.114s per plane]
# FFT timing for 15 DCR planes: [6.992s | 0.466s per plane]
# FFT timing for 15 DCR planes: [1.939s | 0.129s per plane]
# FFT timing for 15 DCR planes: [7.211s | 0.481s per plane]
# FFT timing for 15 DCR planes: [1.953s | 0.130s per plane]
# FFT timing for 15 DCR planes: [7.262s | 0.484s per plane]
# Selecting 10 obs from field 2576, with seeing range 0.619 to 1.106 and airmass range 1.119 to 1.200
# Number and flux contribution of stars of each type:
#  [M 69157| 1.73%] [K 10685| 2.16%] [G 6796| 3.86%] [F 2687| 4.59%] [A 564| 14.89%] [B 111| 72.77%] [O 0| 0.00%]
# Simulating 2479 stars within observable region
# Time to model 2464 stars: [12.893s | 0.00523s per star]
# Time to model 15 bright stars: [11.519s | 0.76792s per star]
# Simulating 239 quasars within observable region
# Time to model 239 stars: [2.897s | 0.01212s per star]
# Writing 6267 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  6.2407183228272425 22.673530195451143
# FFT timing for 15 DCR planes: [2.305s | 0.154s per plane]
# FFT timing for 15 DCR planes: [9.032s | 0.602s per plane]
# FFT timing for 15 DCR planes: [1.770s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.134s | 0.476s per plane]
# FFT timing for 15 DCR planes: [1.802s | 0.120s per plane]
# FFT timing for 15 DCR planes: [8.861s | 0.591s per plane]
# FFT timing for 15 DCR planes: [2.055s | 0.137s per plane]
# FFT timing for 15 DCR planes: [8.640s | 0.576s per plane]
# FFT timing for 15 DCR planes: [1.749s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.745s | 0.516s per plane]
# FFT timing for 15 DCR planes: [1.735s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.368s | 0.491s per plane]
# FFT timing for 15 DCR planes: [2.043s | 0.136s per plane]
# FFT timing for 15 DCR planes: [8.127s | 0.542s per plane]
# FFT timing for 15 DCR planes: [1.784s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.656s | 0.510s per plane]
# FFT timing for 15 DCR planes: [1.983s | 0.132s per plane]
# FFT timing for 15 DCR planes: [7.613s | 0.508s per plane]
# FFT timing for 15 DCR planes: [1.745s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.806s | 0.520s per plane]
# FFT timing for 15 DCR planes: [1.807s | 0.120s per plane]
# FFT timing for 15 DCR planes: [8.084s | 0.539s per plane]
# FFT timing for 15 DCR planes: [1.915s | 0.128s per plane]
# FFT timing for 15 DCR planes: [7.790s | 0.519s per plane]
# FFT timing for 15 DCR planes: [1.828s | 0.122s per plane]
# FFT timing for 15 DCR planes: [8.529s | 0.569s per plane]
# FFT timing for 15 DCR planes: [1.794s | 0.120s per plane]
# FFT timing for 15 DCR planes: [8.175s | 0.545s per plane]
# FFT timing for 15 DCR planes: [1.868s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.102s | 0.473s per plane]
# FFT timing for 15 DCR planes: [1.881s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.064s | 0.471s per plane]
# FFT timing for 15 DCR planes: [1.862s | 0.124s per plane]
# FFT timing for 15 DCR planes: [7.614s | 0.508s per plane]
# FFT timing for 15 DCR planes: [1.728s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.552s | 0.503s per plane]
# FFT timing for 15 DCR planes: [1.913s | 0.128s per plane]
# FFT timing for 15 DCR planes: [8.158s | 0.544s per plane]
# FFT timing for 15 DCR planes: [1.803s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.056s | 0.470s per plane]
# Selecting 9 randomized obs from field 2576, with seeing range 0.529 to 1.064 and airmass range 1.016 to 1.509
# FFT timing for 15 DCR planes: [1.700s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.080s | 0.472s per plane]
# FFT timing for 15 DCR planes: [1.752s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.554s | 0.504s per plane]
# FFT timing for 15 DCR planes: [1.816s | 0.121s per plane]
# FFT timing for 15 DCR planes: [7.981s | 0.532s per plane]
# FFT timing for 15 DCR planes: [1.851s | 0.123s per plane]
# FFT timing for 15 DCR planes: [7.695s | 0.513s per plane]
# FFT timing for 15 DCR planes: [1.818s | 0.121s per plane]
# FFT timing for 15 DCR planes: [7.744s | 0.516s per plane]
# FFT timing for 15 DCR planes: [1.758s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.481s | 0.499s per plane]
# FFT timing for 15 DCR planes: [1.749s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.957s | 0.530s per plane]
# FFT timing for 15 DCR planes: [1.750s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.299s | 0.487s per plane]
# FFT timing for 15 DCR planes: [1.945s | 0.130s per plane]
# FFT timing for 15 DCR planes: [7.308s | 0.487s per plane]
# FFT timing for 15 DCR planes: [1.825s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.326s | 0.488s per plane]
# FFT timing for 15 DCR planes: [1.944s | 0.130s per plane]
# FFT timing for 15 DCR planes: [7.352s | 0.490s per plane]
# FFT timing for 15 DCR planes: [1.758s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.275s | 0.485s per plane]
# FFT timing for 15 DCR planes: [1.744s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.479s | 0.499s per plane]
# FFT timing for 15 DCR planes: [1.913s | 0.128s per plane]
# FFT timing for 15 DCR planes: [7.294s | 0.486s per plane]
# FFT timing for 15 DCR planes: [2.417s | 0.161s per plane]
# FFT timing for 15 DCR planes: [7.351s | 0.490s per plane]
# FFT timing for 15 DCR planes: [1.793s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.599s | 0.507s per plane]
# FFT timing for 15 DCR planes: [1.781s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.337s | 0.489s per plane]
# FFT timing for 15 DCR planes: [2.004s | 0.134s per plane]
# FFT timing for 15 DCR planes: [8.202s | 0.547s per plane]
# Selecting 10 obs from field 2585, with seeing range 0.679 to 1.223 and airmass range 1.132 to 1.177
# Number and flux contribution of stars of each type:
#  [M 69157| 1.73%] [K 10685| 2.16%] [G 6796| 3.86%] [F 2687| 4.59%] [A 564| 14.89%] [B 111| 72.77%] [O 0| 0.00%]
# Simulating 2493 stars within observable region
# Time to model 2483 stars: [14.659s | 0.00590s per star]
# Time to model 10 bright stars: [12.763s | 1.27625s per star]
# Simulating 240 quasars within observable region
# Time to model 240 stars: [2.900s | 0.01208s per star]
# Writing 6267 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  6.2407183228272425 22.673530195451143
# FFT timing for 15 DCR planes: [1.719s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.821s | 0.521s per plane]
# FFT timing for 15 DCR planes: [1.771s | 0.118s per plane]
# FFT timing for 15 DCR planes: [6.888s | 0.459s per plane]
# FFT timing for 15 DCR planes: [1.715s | 0.114s per plane]
# FFT timing for 15 DCR planes: [6.956s | 0.464s per plane]
# FFT timing for 15 DCR planes: [1.685s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.968s | 0.465s per plane]
# FFT timing for 15 DCR planes: [1.717s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.368s | 0.491s per plane]
# FFT timing for 15 DCR planes: [2.801s | 0.187s per plane]
# FFT timing for 15 DCR planes: [8.991s | 0.599s per plane]
# FFT timing for 15 DCR planes: [1.735s | 0.116s per plane]
# FFT timing for 15 DCR planes: [8.822s | 0.588s per plane]
# FFT timing for 15 DCR planes: [1.708s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.113s | 0.474s per plane]
# FFT timing for 15 DCR planes: [1.727s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.949s | 0.530s per plane]
# FFT timing for 15 DCR planes: [2.295s | 0.153s per plane]
# FFT timing for 15 DCR planes: [7.002s | 0.467s per plane]
# FFT timing for 15 DCR planes: [1.708s | 0.114s per plane]
# FFT timing for 15 DCR planes: [9.093s | 0.606s per plane]
# FFT timing for 15 DCR planes: [1.775s | 0.118s per plane]
# FFT timing for 15 DCR planes: [10.205s | 0.680s per plane]
# FFT timing for 15 DCR planes: [1.941s | 0.129s per plane]
# FFT timing for 15 DCR planes: [7.485s | 0.499s per plane]
# FFT timing for 15 DCR planes: [1.754s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.142s | 0.476s per plane]
# FFT timing for 15 DCR planes: [1.873s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.243s | 0.483s per plane]
# FFT timing for 15 DCR planes: [2.000s | 0.133s per plane]
# FFT timing for 15 DCR planes: [8.122s | 0.541s per plane]
# FFT timing for 15 DCR planes: [1.972s | 0.131s per plane]
# FFT timing for 15 DCR planes: [7.740s | 0.516s per plane]
# FFT timing for 15 DCR planes: [1.774s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.880s | 0.525s per plane]
# FFT timing for 15 DCR planes: [1.780s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.369s | 0.491s per plane]
# FFT timing for 15 DCR planes: [1.898s | 0.127s per plane]
# FFT timing for 15 DCR planes: [7.223s | 0.482s per plane]
# Selecting 9 randomized obs from field 2585, with seeing range 0.704 to 1.428 and airmass range 1.009 to 1.325
# FFT timing for 15 DCR planes: [1.677s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.976s | 0.465s per plane]
# FFT timing for 15 DCR planes: [1.668s | 0.111s per plane]
# FFT timing for 15 DCR planes: [7.257s | 0.484s per plane]
# FFT timing for 15 DCR planes: [1.920s | 0.128s per plane]
# FFT timing for 15 DCR planes: [7.126s | 0.475s per plane]
# FFT timing for 15 DCR planes: [1.902s | 0.127s per plane]
# FFT timing for 15 DCR planes: [7.238s | 0.483s per plane]
# FFT timing for 15 DCR planes: [1.822s | 0.121s per plane]
# FFT timing for 15 DCR planes: [7.081s | 0.472s per plane]
# FFT timing for 15 DCR planes: [1.831s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.205s | 0.480s per plane]
# FFT timing for 15 DCR planes: [1.710s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.275s | 0.485s per plane]
# FFT timing for 15 DCR planes: [2.218s | 0.148s per plane]
# FFT timing for 15 DCR planes: [7.288s | 0.486s per plane]
# FFT timing for 15 DCR planes: [2.332s | 0.155s per plane]
# FFT timing for 15 DCR planes: [7.298s | 0.487s per plane]
# FFT timing for 15 DCR planes: [1.690s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.309s | 0.487s per plane]
# FFT timing for 15 DCR planes: [1.806s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.535s | 0.502s per plane]
# FFT timing for 15 DCR planes: [1.945s | 0.130s per plane]
# FFT timing for 15 DCR planes: [7.679s | 0.512s per plane]
# FFT timing for 15 DCR planes: [1.680s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.979s | 0.465s per plane]
# FFT timing for 15 DCR planes: [1.696s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.643s | 0.510s per plane]
# FFT timing for 15 DCR planes: [2.509s | 0.167s per plane]
# FFT timing for 15 DCR planes: [8.578s | 0.572s per plane]
# FFT timing for 15 DCR planes: [1.752s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.350s | 0.490s per plane]
# FFT timing for 15 DCR planes: [1.763s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.075s | 0.472s per plane]
# FFT timing for 15 DCR planes: [1.928s | 0.129s per plane]
# FFT timing for 15 DCR planes: [7.012s | 0.467s per plane]
# Selecting 12 obs from field 2733, with seeing range 0.544 to 0.893 and airmass range 1.172 to 1.257
# Number and flux contribution of stars of each type:
#  [M 69157| 1.73%] [K 10685| 2.16%] [G 6796| 3.86%] [F 2687| 4.59%] [A 564| 14.89%] [B 111| 72.77%] [O 0| 0.00%]
# Simulating 2380 stars within observable region
# Time to model 2375 stars: [13.994s | 0.00589s per star]
# Time to model 5 bright stars: [11.138s | 2.22753s per star]
# Simulating 265 quasars within observable region
# Time to model 264 stars: [2.907s | 0.01101s per star]
# Time to model 1 bright star: [9.627s]
# Writing 6267 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  6.2407183228272425 22.673530195451143
# FFT timing for 15 DCR planes: [1.944s | 0.130s per plane]
# FFT timing for 15 DCR planes: [7.768s | 0.518s per plane]
# FFT timing for 15 DCR planes: [1.716s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.169s | 0.478s per plane]
# FFT timing for 15 DCR planes: [1.864s | 0.124s per plane]
# FFT timing for 15 DCR planes: [7.494s | 0.500s per plane]
# FFT timing for 15 DCR planes: [1.698s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.555s | 0.504s per plane]
# FFT timing for 15 DCR planes: [1.688s | 0.113s per plane]
# FFT timing for 15 DCR planes: [6.960s | 0.464s per plane]
# FFT timing for 15 DCR planes: [1.704s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.052s | 0.470s per plane]
# FFT timing for 15 DCR planes: [1.666s | 0.111s per plane]
# FFT timing for 15 DCR planes: [7.156s | 0.477s per plane]
# FFT timing for 15 DCR planes: [1.689s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.421s | 0.495s per plane]
# FFT timing for 15 DCR planes: [1.713s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.146s | 0.476s per plane]
# FFT timing for 15 DCR planes: [2.447s | 0.163s per plane]
# FFT timing for 15 DCR planes: [7.162s | 0.477s per plane]
# FFT timing for 15 DCR planes: [1.785s | 0.119s per plane]
# FFT timing for 15 DCR planes: [9.322s | 0.621s per plane]
# FFT timing for 15 DCR planes: [1.694s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.925s | 0.528s per plane]
# FFT timing for 15 DCR planes: [1.846s | 0.123s per plane]
# FFT timing for 15 DCR planes: [7.638s | 0.509s per plane]
# FFT timing for 15 DCR planes: [1.838s | 0.123s per plane]
# FFT timing for 15 DCR planes: [7.022s | 0.468s per plane]
# FFT timing for 15 DCR planes: [2.098s | 0.140s per plane]
# FFT timing for 15 DCR planes: [7.276s | 0.485s per plane]
# FFT timing for 15 DCR planes: [1.803s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.397s | 0.493s per plane]
# FFT timing for 15 DCR planes: [1.680s | 0.112s per plane]
# FFT timing for 15 DCR planes: [7.161s | 0.477s per plane]
# FFT timing for 15 DCR planes: [1.690s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.479s | 0.499s per plane]
# FFT timing for 15 DCR planes: [1.878s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.087s | 0.472s per plane]
# FFT timing for 15 DCR planes: [1.692s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.082s | 0.472s per plane]
# FFT timing for 15 DCR planes: [1.828s | 0.122s per plane]
# FFT timing for 15 DCR planes: [8.878s | 0.592s per plane]
# FFT timing for 15 DCR planes: [2.046s | 0.136s per plane]
# FFT timing for 15 DCR planes: [7.774s | 0.518s per plane]
# FFT timing for 15 DCR planes: [1.678s | 0.112s per plane]
# FFT timing for 15 DCR planes: [8.496s | 0.566s per plane]
# FFT timing for 15 DCR planes: [1.698s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.977s | 0.532s per plane]
# Selecting 12 randomized obs from field 2733, with seeing range 0.687 to 1.440 and airmass range 1.016 to 1.297
# FFT timing for 15 DCR planes: [1.692s | 0.113s per plane]
# FFT timing for 15 DCR planes: [6.986s | 0.466s per plane]
# FFT timing for 15 DCR planes: [2.192s | 0.146s per plane]
# FFT timing for 15 DCR planes: [7.499s | 0.500s per plane]
# FFT timing for 15 DCR planes: [1.727s | 0.115s per plane]
# FFT timing for 15 DCR planes: [8.084s | 0.539s per plane]
# FFT timing for 15 DCR planes: [2.235s | 0.149s per plane]
# FFT timing for 15 DCR planes: [7.759s | 0.517s per plane]
# FFT timing for 15 DCR planes: [1.729s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.275s | 0.485s per plane]
# FFT timing for 15 DCR planes: [1.895s | 0.126s per plane]
# FFT timing for 15 DCR planes: [8.217s | 0.548s per plane]
# FFT timing for 15 DCR planes: [1.838s | 0.123s per plane]
# FFT timing for 15 DCR planes: [8.232s | 0.549s per plane]
# FFT timing for 15 DCR planes: [1.800s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.653s | 0.510s per plane]
# FFT timing for 15 DCR planes: [1.717s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.387s | 0.492s per plane]
# FFT timing for 15 DCR planes: [1.717s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.203s | 0.480s per plane]
# FFT timing for 15 DCR planes: [1.850s | 0.123s per plane]
# FFT timing for 15 DCR planes: [7.617s | 0.508s per plane]
# FFT timing for 15 DCR planes: [1.804s | 0.120s per plane]
# FFT timing for 15 DCR planes: [8.155s | 0.544s per plane]
# FFT timing for 15 DCR planes: [1.824s | 0.122s per plane]
# FFT timing for 15 DCR planes: [8.433s | 0.562s per plane]
# FFT timing for 15 DCR planes: [1.879s | 0.125s per plane]
# FFT timing for 15 DCR planes: [8.643s | 0.576s per plane]
# FFT timing for 15 DCR planes: [1.879s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.198s | 0.480s per plane]
# FFT timing for 15 DCR planes: [1.724s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.128s | 0.475s per plane]
# FFT timing for 15 DCR planes: [1.827s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.222s | 0.481s per plane]
# FFT timing for 15 DCR planes: [1.929s | 0.129s per plane]
# FFT timing for 15 DCR planes: [7.244s | 0.483s per plane]
# FFT timing for 15 DCR planes: [1.879s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.185s | 0.479s per plane]
# FFT timing for 15 DCR planes: [1.765s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.737s | 0.516s per plane]
# FFT timing for 15 DCR planes: [1.737s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.153s | 0.477s per plane]
# FFT timing for 15 DCR planes: [2.572s | 0.171s per plane]
# FFT timing for 15 DCR planes: [7.084s | 0.472s per plane]
# FFT timing for 15 DCR planes: [1.804s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.502s | 0.500s per plane]
# FFT timing for 15 DCR planes: [1.744s | 0.116s per plane]
# FFT timing for 15 DCR planes: [8.787s | 0.586s per plane]
# Selecting 4 obs from field 2673, with seeing range 0.708 to 1.125 and airmass range 1.158 to 1.209
# Number and flux contribution of stars of each type:
#  [M 69157| 1.73%] [K 10685| 2.16%] [G 6796| 3.86%] [F 2687| 4.59%] [A 564| 14.89%] [B 111| 72.77%] [O 0| 0.00%]
# Simulating 2504 stars within observable region
# Time to model 2495 stars: [13.870s | 0.00556s per star]
# Time to model 9 bright stars: [11.280s | 1.25329s per star]
# Simulating 252 quasars within observable region
# Time to model 251 stars: [2.801s | 0.01116s per star]
# Time to model 1 bright star: [8.673s]
# Writing 6267 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  6.2407183228272425 22.673530195451143
# FFT timing for 15 DCR planes: [2.753s | 0.184s per plane]
# FFT timing for 15 DCR planes: [11.872s | 0.791s per plane]
# FFT timing for 15 DCR planes: [3.522s | 0.235s per plane]
# FFT timing for 15 DCR planes: [14.300s | 0.953s per plane]
# FFT timing for 15 DCR planes: [2.660s | 0.177s per plane]
# FFT timing for 15 DCR planes: [12.517s | 0.834s per plane]
# FFT timing for 15 DCR planes: [2.877s | 0.192s per plane]
# FFT timing for 15 DCR planes: [13.439s | 0.896s per plane]
# FFT timing for 15 DCR planes: [2.688s | 0.179s per plane]
# FFT timing for 15 DCR planes: [10.931s | 0.729s per plane]
# FFT timing for 15 DCR planes: [2.590s | 0.173s per plane]
# FFT timing for 15 DCR planes: [11.490s | 0.766s per plane]
# FFT timing for 15 DCR planes: [2.911s | 0.194s per plane]
# FFT timing for 15 DCR planes: [10.846s | 0.723s per plane]
# FFT timing for 15 DCR planes: [3.256s | 0.217s per plane]
# FFT timing for 15 DCR planes: [9.251s | 0.617s per plane]
# Selecting 7 randomized obs from field 2673, with seeing range 0.710 to 1.065 and airmass range 1.040 to 1.710
# FFT timing for 15 DCR planes: [1.823s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.274s | 0.485s per plane]
# FFT timing for 15 DCR planes: [1.751s | 0.117s per plane]
# FFT timing for 15 DCR planes: [8.227s | 0.548s per plane]
# FFT timing for 15 DCR planes: [2.213s | 0.148s per plane]
# FFT timing for 15 DCR planes: [10.259s | 0.684s per plane]
# FFT timing for 15 DCR planes: [3.504s | 0.234s per plane]
# FFT timing for 15 DCR planes: [9.770s | 0.651s per plane]
# FFT timing for 15 DCR planes: [2.330s | 0.155s per plane]
# FFT timing for 15 DCR planes: [11.364s | 0.758s per plane]
# FFT timing for 15 DCR planes: [2.464s | 0.164s per plane]
# FFT timing for 15 DCR planes: [11.202s | 0.747s per plane]
# FFT timing for 15 DCR planes: [2.403s | 0.160s per plane]
# FFT timing for 15 DCR planes: [10.806s | 0.720s per plane]
# FFT timing for 15 DCR planes: [3.243s | 0.216s per plane]
# FFT timing for 15 DCR planes: [13.298s | 0.887s per plane]
# FFT timing for 15 DCR planes: [2.824s | 0.188s per plane]
# FFT timing for 15 DCR planes: [11.101s | 0.740s per plane]
# FFT timing for 15 DCR planes: [2.291s | 0.153s per plane]
# FFT timing for 15 DCR planes: [10.839s | 0.723s per plane]
# FFT timing for 15 DCR planes: [3.060s | 0.204s per plane]
# FFT timing for 15 DCR planes: [10.556s | 0.704s per plane]
# FFT timing for 15 DCR planes: [2.502s | 0.167s per plane]
# FFT timing for 15 DCR planes: [11.898s | 0.793s per plane]
# FFT timing for 15 DCR planes: [2.948s | 0.197s per plane]
# FFT timing for 15 DCR planes: [11.322s | 0.755s per plane]
# FFT timing for 15 DCR planes: [2.377s | 0.158s per plane]
# FFT timing for 15 DCR planes: [10.319s | 0.688s per plane]
# Selecting 10 obs from field 2775, with seeing range 0.690 to 1.160 and airmass range 1.206 to 1.255
# Number and flux contribution of stars of each type:
#  [M 69157| 1.73%] [K 10685| 2.16%] [G 6796| 3.86%] [F 2687| 4.59%] [A 564| 14.89%] [B 111| 72.77%] [O 0| 0.00%]
# Simulating 2451 stars within observable region
# Time to model 2438 stars: [17.586s | 0.00721s per star]
# Time to model 13 bright stars: [22.380s | 1.72151s per star]
# Simulating 254 quasars within observable region
# Time to model 252 stars: [4.154s | 0.01648s per star]
# Time to model 2 bright stars: [13.584s | 6.79189s per star]
# Writing 6267 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  6.2407183228272425 22.673530195451143
# FFT timing for 15 DCR planes: [1.932s | 0.129s per plane]
# FFT timing for 15 DCR planes: [8.745s | 0.583s per plane]
# FFT timing for 15 DCR planes: [1.880s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.904s | 0.527s per plane]
# FFT timing for 15 DCR planes: [1.860s | 0.124s per plane]
# FFT timing for 15 DCR planes: [7.236s | 0.482s per plane]
# FFT timing for 15 DCR planes: [1.716s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.799s | 0.520s per plane]
# FFT timing for 15 DCR planes: [1.774s | 0.118s per plane]
# FFT timing for 15 DCR planes: [9.159s | 0.611s per plane]
# FFT timing for 15 DCR planes: [1.705s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.093s | 0.473s per plane]
# FFT timing for 15 DCR planes: [1.716s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.011s | 0.467s per plane]
# FFT timing for 15 DCR planes: [1.709s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.024s | 0.468s per plane]
# FFT timing for 15 DCR planes: [1.691s | 0.113s per plane]
# FFT timing for 15 DCR planes: [8.251s | 0.550s per plane]
# FFT timing for 15 DCR planes: [1.738s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.081s | 0.472s per plane]
# FFT timing for 15 DCR planes: [1.697s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.328s | 0.489s per plane]
# FFT timing for 15 DCR planes: [2.131s | 0.142s per plane]
# FFT timing for 15 DCR planes: [7.744s | 0.516s per plane]
# FFT timing for 15 DCR planes: [1.963s | 0.131s per plane]
# FFT timing for 15 DCR planes: [7.109s | 0.474s per plane]
# FFT timing for 15 DCR planes: [1.879s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.121s | 0.475s per plane]
# FFT timing for 15 DCR planes: [1.714s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.450s | 0.497s per plane]
# FFT timing for 15 DCR planes: [1.798s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.348s | 0.490s per plane]
# FFT timing for 15 DCR planes: [1.721s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.329s | 0.489s per plane]
# FFT timing for 15 DCR planes: [2.045s | 0.136s per plane]
# FFT timing for 15 DCR planes: [7.352s | 0.490s per plane]
# FFT timing for 15 DCR planes: [1.739s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.123s | 0.475s per plane]
# FFT timing for 15 DCR planes: [1.863s | 0.124s per plane]
# FFT timing for 15 DCR planes: [7.034s | 0.469s per plane]
# Selecting 5 randomized obs from field 2775, with seeing range 0.655 to 0.985 and airmass range 1.026 to 1.109
# FFT timing for 15 DCR planes: [1.733s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.018s | 0.468s per plane]
# FFT timing for 15 DCR planes: [1.684s | 0.112s per plane]
# FFT timing for 15 DCR planes: [7.537s | 0.502s per plane]
# FFT timing for 15 DCR planes: [1.846s | 0.123s per plane]
# FFT timing for 15 DCR planes: [7.878s | 0.525s per plane]
# FFT timing for 15 DCR planes: [2.487s | 0.166s per plane]
# FFT timing for 15 DCR planes: [9.844s | 0.656s per plane]
# FFT timing for 15 DCR planes: [2.077s | 0.138s per plane]
# FFT timing for 15 DCR planes: [7.978s | 0.532s per plane]
# FFT timing for 15 DCR planes: [1.822s | 0.121s per plane]
# FFT timing for 15 DCR planes: [7.146s | 0.476s per plane]
# FFT timing for 15 DCR planes: [1.715s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.458s | 0.497s per plane]
# FFT timing for 15 DCR planes: [1.799s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.796s | 0.520s per plane]
# FFT timing for 15 DCR planes: [1.778s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.179s | 0.479s per plane]
# FFT timing for 15 DCR planes: [1.731s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.521s | 0.501s per plane]

# %% [markdown]
# Make a text file containing the visit list

# %%
visits = None
mosaic = True
randomize_conditions = False
band_dict = {'u': 0, 'g': 1, 'r': 2, 'i': 3, 'z': 4, 'y': 5}
for d_y, n_obs in zip(dither_y, n_obs_list):
    rng = np.random.RandomState(n_obs + 2)
    for rpt in range(repeat_obs):
        d_x = dither_x[rpt]
        index = int(np.rint(rng.rand()*1000))
        opsim.set_field(n_obs=n_obs, index=index, year=template_year)
        n_obs1 = len(opsim.airmass)
        opsim.update_year(alert_year, randomize_conditions=randomize_conditions)
        n_obs2 = len(opsim.airmass)
        if mosaic:
            visit_name1 = "%i" % (100*opsim.field_Id + 1000000*template_year)
            visit_name1b = "%i" % (100*opsim.field_Id + 1000000*template_year + n_obs1 - 1)
            visit_name2 = "%i" % (100*opsim.field_Id + 1000000*alert_year)
            visit_name2b = "%i" % (100*opsim.field_Id + 1000000*alert_year + n_obs2 - 1)
        else:
            visit_name1 = "%i" % (100*band_dict[opsim.filter] + 1000*template_year)
            visit_name1b = "%i" % (100*band_dict[opsim.filter] + 1000*template_year + n_obs1 - 1)
            visit_name2 = "%i" % (100*band_dict[opsim.filter] + 1000*alert_year)
            visit_name2b = "%i" % (100*band_dict[opsim.filter] + 1000*alert_year + n_obs2 - 1)
        if visits is None:
            visits = visit_name1
        else:
            visits += "^" + visit_name1
        visits += "..%s^%s..%s" % (visit_name1b, visit_name2, visit_name2b)
# Out:
# Selecting 10 obs from field 2682, with seeing range 0.541 to 0.815 and airmass range 1.158 to 1.209
# Selecting 8 obs from field 2725, with seeing range 0.699 to 1.011 and airmass range 1.167 to 1.250
# Selecting 6 obs from field 2874, with seeing range 0.575 to 0.759 and airmass range 1.204 to 1.271
# Selecting 12 obs from field 359, with seeing range 0.564 to 1.414 and airmass range 1.148 to 1.190
# Selecting 10 obs from field 2576, with seeing range 0.619 to 1.106 and airmass range 1.119 to 1.200
# Selecting 10 obs from field 2585, with seeing range 0.679 to 1.223 and airmass range 1.132 to 1.177
# Selecting 12 obs from field 2733, with seeing range 0.544 to 0.893 and airmass range 1.172 to 1.257
# Selecting 4 obs from field 2673, with seeing range 0.708 to 1.125 and airmass range 1.158 to 1.209
# Selecting 10 obs from field 2775, with seeing range 0.690 to 1.160 and airmass range 1.206 to 1.255

# %%
print(visits)
# Out:
# 1268200..1268209^2268200..2268206^1272500..1272507^2272500..2272512^1287400..1287405^2287400..2287402^1035900..1035911^2035900..2035911^1257600..1257609^2257600..2257608^1258500..1258509^2258500..2258508^1273300..1273311^2273300..2273311^1267300..1267303^2267300..2267306^1277500..1277509^2277500..2277504

# %%
use_seeing = False
output_directory = opsim.sim_directory + "mosaic_%i_constPSF/" % opsim.seed
visits_file = output_directory + "visits.txt"
visits_cmd = "--id visit=" + visits
np.savetxt(visits_file, [visits_cmd], fmt='%s')

# %%
visits_cmd
# Out:
# '--id visit=1268200..1268204^2268200..2268208^1272500..1272504^2272500..2272506^1287400..1287404^2287400..2287401^1035900..1035907^2035900..2035902^1257600..1257607^2257600..2257608^1258500..1258507^2258500..2258506^1273300..1273309^2273300..2273305^1267300..1267309^2267300..2267307^1277500..1277509^2277500..2277511'
