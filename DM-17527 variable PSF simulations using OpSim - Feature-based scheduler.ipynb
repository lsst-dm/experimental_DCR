# %%
import numpy as np
from python.notebook_utils import look
from python.simulation_utils import simulation_wrapper, OpSim_wrapper

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import lsst.afw.display.rgb as rgb

# %% [markdown]
# Load the 2018 baseline survey

# %%
n_obs_list = [5, 8, 10]
repeat_obs = 3  # number of different fields with the given n_obs to generate simulations of
template_year = 1 
alert_year = 2
n_star = 10000
n_quasar = 1000

# %% [markdown]
# Connect to the database and set up for all of the simulations

# %% [markdown]
# Create a second set of simulations where the fields can be mosaiced together

# %%
airmass_threshold = 1.15  # Target fields must include at least one observation above this airmass to be included
opsim = OpSim_wrapper(year=template_year, filt='g', opsim_db='/Users/sullivan/LSST/OpSim/baseline2018a.db',
                      sim_directory="/Users/sullivan/LSST/simulations/OpSim/pontus_2568/",
                      conditions_db="/Users/sullivan/LSST/OpSim/pontus_2568.db",
                      airmass_threshold=airmass_threshold)

# %%
nx = repeat_obs
ny = len(n_obs_list)
n = nx if nx > ny else ny
simulation_size = n
dither_scale = 0.95
dither_x = dither_scale*(np.arange(nx) - (nx - 1)/2)
dither_y = dither_scale*(np.arange(ny) - (ny - 1)/2)

# %%
initial_const = True
initial_var = True
seed = 1
randomize_conditions = True
randomize_template = True

# %%
for d_y, n_obs in zip(dither_y, n_obs_list):
    rng = np.random.RandomState(n_obs + 2)
    for rpt in range(repeat_obs):
        d_x = dither_x[rpt]
        index = int(np.rint(rng.rand()*1000))
        opsim.set_field(n_obs=n_obs, index=index, year=template_year)
        sim = opsim.initialize_simulation(n_star=n_star*n**2, n_quasar=n_quasar*n**2,
                                          dither=(d_x, d_y), seed=seed,
                                          simulation_size=simulation_size)
        if randomize_template:
            opsim.update_year(template_year, randomize_conditions=randomize_conditions)
        opsim.run_simulation(sim, use_seeing=False, write_catalog=initial_const,
                             initialize_directory=initial_const, mosaic=True,
                             randomize_conditions=randomize_conditions)
        opsim.run_simulation(sim, use_seeing=True, write_catalog=False,
                             initialize_directory=initial_var, mosaic=True,
                             randomize_conditions=randomize_conditions)
        initial_const = False
        initial_var = False
        
        opsim.update_year(alert_year, randomize_conditions=randomize_conditions)
        opsim.run_simulation(sim, use_seeing=False, write_catalog=False,
                             initialize_directory=False, mosaic=True,
                             randomize_conditions=randomize_conditions)
        opsim.run_simulation(sim, use_seeing=True, write_catalog=False,
                             initialize_directory=False, mosaic=True,
                             randomize_conditions=randomize_conditions)
# Out:
# Selecting 10 obs from field 2682, with seeing range 0.541 to 0.815 and airmass range 1.158 to 1.209
# Number and flux contribution of stars of each type:
#  [M 68936| 1.57%] [K 10850| 1.94%] [G 6902| 3.70%] [F 2684| 4.66%] [A 516| 13.87%] [B 112| 74.26%] [O 0| 0.00%]
# Simulating 2603 stars within observable region
# Time to model 2594 stars: [12.285s | 0.00474s per star]
# Time to model 9 bright stars: [9.320s | 1.03555s per star]
# Simulating 240 quasars within observable region
# Time to model 239 stars: [2.437s | 0.01020s per star]
# Time to model 1 bright star: [7.965s]
# Selecting 10 randomized obs from field 2682, with seeing range 0.504 to 1.019 and airmass range 1.021 to 1.509
# Writing 6448 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  4.8740708322414195 22.627302179467225
# FFT timing for 15 DCR planes: [2.569s | 0.171s per plane]
# FFT timing for 15 DCR planes: [6.875s | 0.458s per plane]
# ExpId 1268200 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.603s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.737s | 0.449s per plane]
# ExpId 1268201 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.609s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.708s | 0.447s per plane]
# ExpId 1268202 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.657s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.729s | 0.449s per plane]
# ExpId 1268203 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.630s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.784s | 0.452s per plane]
# ExpId 1268204 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.639s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.741s | 0.449s per plane]
# ExpId 1268205 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.611s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.751s | 0.450s per plane]
# ExpId 1268206 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.607s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.725s | 0.448s per plane]
# ExpId 1268207 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.615s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.759s | 0.451s per plane]
# ExpId 1268208 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.649s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.754s | 0.450s per plane]
# ExpId 1268209 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.334s | 0.156s per plane]
# FFT timing for 15 DCR planes: [6.717s | 0.448s per plane]
# ExpId 1268200 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.591s | 0.106s per plane]
# FFT timing for 15 DCR planes: [7.787s | 0.519s per plane]
# ExpId 1268201 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.945s | 0.130s per plane]
# FFT timing for 15 DCR planes: [7.049s | 0.470s per plane]
# ExpId 1268202 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.611s | 0.107s per plane]
# FFT timing for 15 DCR planes: [7.432s | 0.495s per plane]
# ExpId 1268203 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.726s | 0.115s per plane]
# FFT timing for 15 DCR planes: [6.757s | 0.450s per plane]
# ExpId 1268204 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.792s | 0.119s per plane]
# FFT timing for 15 DCR planes: [6.765s | 0.451s per plane]
# ExpId 1268205 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.613s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.715s | 0.448s per plane]
# ExpId 1268206 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.609s | 0.107s per plane]
# FFT timing for 15 DCR planes: [7.332s | 0.489s per plane]
# ExpId 1268207 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.699s | 0.113s per plane]
# FFT timing for 15 DCR planes: [9.434s | 0.629s per plane]
# ExpId 1268208 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.055s | 0.137s per plane]
# FFT timing for 15 DCR planes: [7.481s | 0.499s per plane]
# ExpId 1268209 Az: 180.0, ParAng: nan
# Selecting 7 randomized obs from field 2682, with seeing range 0.675 to 1.210 and airmass range 1.007 to 1.207
# FFT timing for 15 DCR planes: [1.605s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.995s | 0.466s per plane]
# ExpId 2268200 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.685s | 0.112s per plane]
# FFT timing for 15 DCR planes: [7.000s | 0.467s per plane]
# ExpId 2268201 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.366s | 0.158s per plane]
# FFT timing for 15 DCR planes: [8.115s | 0.541s per plane]
# ExpId 2268202 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.737s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.926s | 0.528s per plane]
# ExpId 2268203 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.890s | 0.126s per plane]
# FFT timing for 15 DCR planes: [7.857s | 0.524s per plane]
# ExpId 2268204 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.265s | 0.151s per plane]
# FFT timing for 15 DCR planes: [7.643s | 0.510s per plane]
# ExpId 2268205 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.095s | 0.140s per plane]
# FFT timing for 15 DCR planes: [6.838s | 0.456s per plane]
# ExpId 2268206 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.859s | 0.124s per plane]
# FFT timing for 15 DCR planes: [6.766s | 0.451s per plane]
# ExpId 2268200 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.616s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.762s | 0.451s per plane]
# ExpId 2268201 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.617s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.981s | 0.465s per plane]
# ExpId 2268202 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.679s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.841s | 0.456s per plane]
# ExpId 2268203 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.719s | 0.115s per plane]
# FFT timing for 15 DCR planes: [6.763s | 0.451s per plane]
# ExpId 2268204 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.613s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.769s | 0.451s per plane]
# ExpId 2268205 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.628s | 0.109s per plane]
# FFT timing for 15 DCR planes: [7.579s | 0.505s per plane]
# ExpId 2268206 Az: 0.0, ParAng: nan
# Selecting 8 obs from field 2725, with seeing range 0.699 to 1.011 and airmass range 1.167 to 1.250
# Number and flux contribution of stars of each type:
#  [M 68936| 1.57%] [K 10850| 1.94%] [G 6902| 3.70%] [F 2684| 4.66%] [A 516| 13.87%] [B 112| 74.26%] [O 0| 0.00%]
# Simulating 2595 stars within observable region
# Time to model 2589 stars: [12.657s | 0.00489s per star]
# Time to model 6 bright stars: [10.168s | 1.69465s per star]
# Simulating 251 quasars within observable region
# Time to model 250 stars: [2.586s | 0.01034s per star]
# Time to model 1 bright star: [8.361s]
# Selecting 8 randomized obs from field 2725, with seeing range 0.527 to 1.374 and airmass range 1.025 to 1.292
# Writing 6448 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  4.8740708322414195 22.627302179467225
# FFT timing for 15 DCR planes: [1.908s | 0.127s per plane]
# FFT timing for 15 DCR planes: [7.008s | 0.467s per plane]
# ExpId 1272500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.657s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.766s | 0.451s per plane]
# ExpId 1272501 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.634s | 0.109s per plane]
# FFT timing for 15 DCR planes: [7.071s | 0.471s per plane]
# ExpId 1272502 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.017s | 0.134s per plane]
# FFT timing for 15 DCR planes: [8.019s | 0.535s per plane]
# ExpId 1272503 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.461s | 0.164s per plane]
# FFT timing for 15 DCR planes: [8.290s | 0.553s per plane]
# ExpId 1272504 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.236s | 0.149s per plane]
# FFT timing for 15 DCR planes: [8.174s | 0.545s per plane]
# ExpId 1272505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.625s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.732s | 0.449s per plane]
# ExpId 1272506 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.616s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.729s | 0.449s per plane]
# ExpId 1272507 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.727s | 0.115s per plane]
# FFT timing for 15 DCR planes: [6.802s | 0.453s per plane]
# ExpId 1272500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.985s | 0.132s per plane]
# FFT timing for 15 DCR planes: [8.537s | 0.569s per plane]
# ExpId 1272501 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.649s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.889s | 0.459s per plane]
# ExpId 1272502 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.665s | 0.111s per plane]
# FFT timing for 15 DCR planes: [7.702s | 0.513s per plane]
# ExpId 1272503 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.659s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.792s | 0.453s per plane]
# ExpId 1272504 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.628s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.814s | 0.454s per plane]
# ExpId 1272505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.626s | 0.108s per plane]
# FFT timing for 15 DCR planes: [8.197s | 0.546s per plane]
# ExpId 1272506 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.955s | 0.130s per plane]
# FFT timing for 15 DCR planes: [6.775s | 0.452s per plane]
# ExpId 1272507 Az: 180.0, ParAng: nan
# Selecting 13 randomized obs from field 2725, with seeing range 0.523 to 0.956 and airmass range 1.024 to 1.156
# FFT timing for 15 DCR planes: [1.632s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.734s | 0.449s per plane]
# ExpId 2272500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.593s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.908s | 0.461s per plane]
# ExpId 2272501 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.713s | 0.114s per plane]
# FFT timing for 15 DCR planes: [6.970s | 0.465s per plane]
# ExpId 2272502 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.043s | 0.136s per plane]
# FFT timing for 15 DCR planes: [7.087s | 0.472s per plane]
# ExpId 2272503 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.639s | 0.109s per plane]
# FFT timing for 15 DCR planes: [7.094s | 0.473s per plane]
# ExpId 2272504 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.783s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.140s | 0.476s per plane]
# ExpId 2272505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.640s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.797s | 0.453s per plane]
# ExpId 2272506 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.634s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.701s | 0.447s per plane]
# ExpId 2272507 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.625s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.748s | 0.450s per plane]
# ExpId 2272508 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.666s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.911s | 0.461s per plane]
# ExpId 2272509 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.637s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.743s | 0.450s per plane]
# ExpId 2272510 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.643s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.969s | 0.465s per plane]
# ExpId 2272511 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.715s | 0.114s per plane]
# FFT timing for 15 DCR planes: [6.913s | 0.461s per plane]
# ExpId 2272512 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.716s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.054s | 0.470s per plane]
# ExpId 2272500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.645s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.896s | 0.460s per plane]
# ExpId 2272501 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.735s | 0.116s per plane]
# FFT timing for 15 DCR planes: [6.804s | 0.454s per plane]
# ExpId 2272502 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.668s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.983s | 0.466s per plane]
# ExpId 2272503 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.709s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.189s | 0.479s per plane]
# ExpId 2272504 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.694s | 0.113s per plane]
# FFT timing for 15 DCR planes: [6.785s | 0.452s per plane]
# ExpId 2272505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.620s | 0.108s per plane]
# FFT timing for 15 DCR planes: [7.538s | 0.503s per plane]
# ExpId 2272506 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.634s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.790s | 0.453s per plane]
# ExpId 2272507 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.763s | 0.118s per plane]
# FFT timing for 15 DCR planes: [6.988s | 0.466s per plane]
# ExpId 2272508 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.651s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.929s | 0.462s per plane]
# ExpId 2272509 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.624s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.773s | 0.452s per plane]
# ExpId 2272510 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.865s | 0.124s per plane]
# FFT timing for 15 DCR planes: [6.934s | 0.462s per plane]
# ExpId 2272511 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.254s | 0.150s per plane]
# FFT timing for 15 DCR planes: [6.759s | 0.451s per plane]
# ExpId 2272512 Az: 0.0, ParAng: nan
# Selecting 6 obs from field 2874, with seeing range 0.575 to 0.759 and airmass range 1.204 to 1.271
# Number and flux contribution of stars of each type:
#  [M 68936| 1.57%] [K 10850| 1.94%] [G 6902| 3.70%] [F 2684| 4.66%] [A 516| 13.87%] [B 112| 74.26%] [O 0| 0.00%]
# Simulating 2515 stars within observable region
# Time to model 2506 stars: [11.867s | 0.00474s per star]
# Time to model 9 bright stars: [11.304s | 1.25597s per star]
# Simulating 256 quasars within observable region
# Time to model 254 stars: [3.532s | 0.01391s per star]
# Time to model 2 bright stars: [10.208s | 5.10410s per star]
# Selecting 6 randomized obs from field 2874, with seeing range 0.542 to 0.781 and airmass range 1.034 to 1.247
# Writing 6448 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  4.8740708322414195 22.627302179467225
# FFT timing for 15 DCR planes: [1.822s | 0.121s per plane]
# FFT timing for 15 DCR planes: [7.210s | 0.481s per plane]
# ExpId 1287400 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.698s | 0.113s per plane]
# FFT timing for 15 DCR planes: [7.021s | 0.468s per plane]
# ExpId 1287401 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.706s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.971s | 0.531s per plane]
# ExpId 1287402 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.988s | 0.133s per plane]
# FFT timing for 15 DCR planes: [9.415s | 0.628s per plane]
# ExpId 1287403 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.924s | 0.128s per plane]
# FFT timing for 15 DCR planes: [8.391s | 0.559s per plane]
# ExpId 1287404 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.158s | 0.144s per plane]
# FFT timing for 15 DCR planes: [7.733s | 0.516s per plane]
# ExpId 1287405 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.974s | 0.132s per plane]
# FFT timing for 15 DCR planes: [8.343s | 0.556s per plane]
# ExpId 1287400 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.078s | 0.139s per plane]
# FFT timing for 15 DCR planes: [7.524s | 0.502s per plane]
# ExpId 1287401 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.766s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.032s | 0.469s per plane]
# ExpId 1287402 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.725s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.564s | 0.504s per plane]
# ExpId 1287403 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.768s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.122s | 0.475s per plane]
# ExpId 1287404 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.633s | 0.109s per plane]
# FFT timing for 15 DCR planes: [7.154s | 0.477s per plane]
# ExpId 1287405 Az: 180.0, ParAng: nan
# Selecting 3 randomized obs from field 2874, with seeing range 0.745 to 1.422 and airmass range 1.034 to 1.879
# FFT timing for 15 DCR planes: [1.710s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.603s | 0.507s per plane]
# ExpId 2287400 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.798s | 0.120s per plane]
# FFT timing for 15 DCR planes: [9.049s | 0.603s per plane]
# ExpId 2287401 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.581s | 0.172s per plane]
# FFT timing for 15 DCR planes: [8.364s | 0.558s per plane]
# ExpId 2287402 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.265s | 0.151s per plane]
# FFT timing for 15 DCR planes: [7.669s | 0.511s per plane]
# ExpId 2287400 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.656s | 0.110s per plane]
# FFT timing for 15 DCR planes: [9.361s | 0.624s per plane]
# ExpId 2287401 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.632s | 0.109s per plane]
# FFT timing for 15 DCR planes: [7.640s | 0.509s per plane]
# ExpId 2287402 Az: 0.0, ParAng: nan
# Selecting 12 obs from field 359, with seeing range 0.564 to 1.414 and airmass range 1.148 to 1.190
# Number and flux contribution of stars of each type:
#  [M 68936| 1.57%] [K 10850| 1.94%] [G 6902| 3.70%] [F 2684| 4.66%] [A 516| 13.87%] [B 112| 74.26%] [O 0| 0.00%]
# Simulating 2439 stars within observable region
# Time to model 2425 stars: [17.968s | 0.00741s per star]
# Time to model 14 bright stars: [14.651s | 1.04653s per star]
# Simulating 250 quasars within observable region
# Time to model 250 stars: [3.229s | 0.01292s per star]
# Selecting 12 randomized obs from field 359, with seeing range 0.702 to 1.162 and airmass range 1.030 to 2.025
# Writing 6448 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  4.8740708322414195 22.627302179467225
# FFT timing for 15 DCR planes: [1.902s | 0.127s per plane]
# FFT timing for 15 DCR planes: [8.300s | 0.553s per plane]
# ExpId 1035900 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.873s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.298s | 0.487s per plane]
# ExpId 1035901 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.769s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.173s | 0.478s per plane]
# ExpId 1035902 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.661s | 0.111s per plane]
# FFT timing for 15 DCR planes: [7.351s | 0.490s per plane]
# ExpId 1035903 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.721s | 0.115s per plane]
# FFT timing for 15 DCR planes: [6.940s | 0.463s per plane]
# ExpId 1035904 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.912s | 0.127s per plane]
# FFT timing for 15 DCR planes: [7.990s | 0.533s per plane]
# ExpId 1035905 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.814s | 0.121s per plane]
# FFT timing for 15 DCR planes: [8.600s | 0.573s per plane]
# ExpId 1035906 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.908s | 0.127s per plane]
# FFT timing for 15 DCR planes: [9.292s | 0.619s per plane]
# ExpId 1035907 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.074s | 0.138s per plane]
# FFT timing for 15 DCR planes: [8.975s | 0.598s per plane]
# ExpId 1035908 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.874s | 0.125s per plane]
# FFT timing for 15 DCR planes: [8.642s | 0.576s per plane]
# ExpId 1035909 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.878s | 0.125s per plane]
# FFT timing for 15 DCR planes: [8.869s | 0.591s per plane]
# ExpId 1035910 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.691s | 0.113s per plane]
# FFT timing for 15 DCR planes: [8.369s | 0.558s per plane]
# ExpId 1035911 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.002s | 0.133s per plane]
# FFT timing for 15 DCR planes: [7.400s | 0.493s per plane]
# ExpId 1035900 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.790s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.787s | 0.519s per plane]
# ExpId 1035901 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.718s | 0.115s per plane]
# FFT timing for 15 DCR planes: [7.429s | 0.495s per plane]
# ExpId 1035902 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.666s | 0.111s per plane]
# FFT timing for 15 DCR planes: [7.080s | 0.472s per plane]
# ExpId 1035903 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.728s | 0.115s per plane]
# FFT timing for 15 DCR planes: [8.370s | 0.558s per plane]
# ExpId 1035904 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.212s | 0.147s per plane]
# FFT timing for 15 DCR planes: [7.423s | 0.495s per plane]
# ExpId 1035905 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.690s | 0.113s per plane]
# FFT timing for 15 DCR planes: [6.851s | 0.457s per plane]
# ExpId 1035906 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.597s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.695s | 0.446s per plane]
# ExpId 1035907 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.632s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.706s | 0.447s per plane]
# ExpId 1035908 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.800s | 0.120s per plane]
# FFT timing for 15 DCR planes: [6.976s | 0.465s per plane]
# ExpId 1035909 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.045s | 0.136s per plane]
# FFT timing for 15 DCR planes: [6.990s | 0.466s per plane]
# ExpId 1035910 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.232s | 0.149s per plane]
# FFT timing for 15 DCR planes: [8.349s | 0.557s per plane]
# ExpId 1035911 Az: 0.0, ParAng: nan
# Selecting 12 randomized obs from field 359, with seeing range 0.694 to 0.984 and airmass range 1.010 to 1.195
# FFT timing for 15 DCR planes: [1.701s | 0.113s per plane]
# FFT timing for 15 DCR planes: [8.446s | 0.563s per plane]
# ExpId 2035900 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.002s | 0.133s per plane]
# FFT timing for 15 DCR planes: [8.101s | 0.540s per plane]
# ExpId 2035901 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.769s | 0.118s per plane]
# FFT timing for 15 DCR planes: [6.784s | 0.452s per plane]
# ExpId 2035902 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.618s | 0.108s per plane]
# FFT timing for 15 DCR planes: [7.197s | 0.480s per plane]
# ExpId 2035903 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.613s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.734s | 0.449s per plane]
# ExpId 2035904 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.611s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.915s | 0.461s per plane]
# ExpId 2035905 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.760s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.348s | 0.490s per plane]
# ExpId 2035906 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.605s | 0.107s per plane]
# FFT timing for 15 DCR planes: [7.133s | 0.476s per plane]
# ExpId 2035907 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.782s | 0.119s per plane]
# FFT timing for 15 DCR planes: [6.967s | 0.464s per plane]
# ExpId 2035908 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.916s | 0.128s per plane]
# FFT timing for 15 DCR planes: [9.786s | 0.652s per plane]
# ExpId 2035909 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.142s | 0.143s per plane]
# FFT timing for 15 DCR planes: [7.016s | 0.468s per plane]
# ExpId 2035910 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.878s | 0.125s per plane]
# FFT timing for 15 DCR planes: [8.162s | 0.544s per plane]
# ExpId 2035911 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.630s | 0.109s per plane]
# FFT timing for 15 DCR planes: [7.585s | 0.506s per plane]
# ExpId 2035900 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.897s | 0.126s per plane]
# FFT timing for 15 DCR planes: [6.938s | 0.463s per plane]
# ExpId 2035901 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.799s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.320s | 0.488s per plane]
# ExpId 2035902 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.802s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.386s | 0.492s per plane]
# ExpId 2035903 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.822s | 0.121s per plane]
# FFT timing for 15 DCR planes: [6.955s | 0.464s per plane]
# ExpId 2035904 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.649s | 0.110s per plane]
# FFT timing for 15 DCR planes: [7.389s | 0.493s per plane]
# ExpId 2035905 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.831s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.743s | 0.516s per plane]
# ExpId 2035906 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.802s | 0.120s per plane]
# FFT timing for 15 DCR planes: [6.771s | 0.451s per plane]
# ExpId 2035907 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.694s | 0.113s per plane]
# FFT timing for 15 DCR planes: [8.762s | 0.584s per plane]
# ExpId 2035908 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.203s | 0.147s per plane]
# FFT timing for 15 DCR planes: [6.844s | 0.456s per plane]
# ExpId 2035909 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.798s | 0.120s per plane]
# FFT timing for 15 DCR planes: [8.240s | 0.549s per plane]
# ExpId 2035910 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.218s | 0.148s per plane]
# FFT timing for 15 DCR planes: [7.983s | 0.532s per plane]
# ExpId 2035911 Az: 180.0, ParAng: nan
# Selecting 10 obs from field 2576, with seeing range 0.619 to 1.106 and airmass range 1.119 to 1.200
# Number and flux contribution of stars of each type:
#  [M 68936| 1.57%] [K 10850| 1.94%] [G 6902| 3.70%] [F 2684| 4.66%] [A 516| 13.87%] [B 112| 74.26%] [O 0| 0.00%]
# Simulating 2418 stars within observable region
# Time to model 2410 stars: [16.042s | 0.00666s per star]
# Time to model 8 bright stars: [15.020s | 1.87749s per star]
# Simulating 267 quasars within observable region
# Time to model 266 stars: [3.646s | 0.01371s per star]
# Time to model 1 bright star: [8.374s]
# Selecting 10 randomized obs from field 2576, with seeing range 0.533 to 1.586 and airmass range 1.029 to 1.685
# Writing 6448 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  4.8740708322414195 22.627302179467225
# FFT timing for 15 DCR planes: [2.161s | 0.144s per plane]
# FFT timing for 15 DCR planes: [8.012s | 0.534s per plane]
# ExpId 1257600 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.622s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.790s | 0.453s per plane]
# ExpId 1257601 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.619s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.912s | 0.461s per plane]
# ExpId 1257602 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.606s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.728s | 0.449s per plane]
# ExpId 1257603 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.713s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.318s | 0.488s per plane]
# ExpId 1257604 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.623s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.900s | 0.460s per plane]
# ExpId 1257605 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.625s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.890s | 0.459s per plane]
# ExpId 1257606 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.602s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.808s | 0.454s per plane]
# ExpId 1257607 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.606s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.752s | 0.450s per plane]
# ExpId 1257608 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.605s | 0.107s per plane]
# FFT timing for 15 DCR planes: [7.734s | 0.516s per plane]
# ExpId 1257609 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.600s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.773s | 0.452s per plane]
# ExpId 1257600 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.890s | 0.126s per plane]
# FFT timing for 15 DCR planes: [6.820s | 0.455s per plane]
# ExpId 1257601 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.805s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.560s | 0.504s per plane]
# ExpId 1257602 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.047s | 0.136s per plane]
# FFT timing for 15 DCR planes: [7.368s | 0.491s per plane]
# ExpId 1257603 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.609s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.734s | 0.449s per plane]
# ExpId 1257604 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.770s | 0.118s per plane]
# FFT timing for 15 DCR planes: [6.727s | 0.448s per plane]
# ExpId 1257605 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.619s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.726s | 0.448s per plane]
# ExpId 1257606 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.618s | 0.108s per plane]
# FFT timing for 15 DCR planes: [7.654s | 0.510s per plane]
# ExpId 1257607 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.668s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.702s | 0.447s per plane]
# ExpId 1257608 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.695s | 0.113s per plane]
# FFT timing for 15 DCR planes: [6.764s | 0.451s per plane]
# ExpId 1257609 Az: 0.0, ParAng: nan
# Selecting 9 randomized obs from field 2576, with seeing range 0.529 to 1.064 and airmass range 1.016 to 1.509
# FFT timing for 15 DCR planes: [1.606s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.711s | 0.447s per plane]
# ExpId 2257600 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.678s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.726s | 0.448s per plane]
# ExpId 2257601 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.620s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.743s | 0.450s per plane]
# ExpId 2257602 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.648s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.741s | 0.449s per plane]
# ExpId 2257603 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.632s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.722s | 0.448s per plane]
# ExpId 2257604 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.641s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.816s | 0.454s per plane]
# ExpId 2257605 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.631s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.957s | 0.464s per plane]
# ExpId 2257606 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.815s | 0.121s per plane]
# FFT timing for 15 DCR planes: [6.696s | 0.446s per plane]
# ExpId 2257607 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.605s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.775s | 0.452s per plane]
# ExpId 2257608 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.601s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.757s | 0.450s per plane]
# ExpId 2257600 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.807s | 0.120s per plane]
# FFT timing for 15 DCR planes: [6.939s | 0.463s per plane]
# ExpId 2257601 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.749s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.435s | 0.496s per plane]
# ExpId 2257602 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.671s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.747s | 0.450s per plane]
# ExpId 2257603 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.663s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.777s | 0.452s per plane]
# ExpId 2257604 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.222s | 0.148s per plane]
# FFT timing for 15 DCR planes: [6.745s | 0.450s per plane]
# ExpId 2257605 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.624s | 0.108s per plane]
# FFT timing for 15 DCR planes: [7.076s | 0.472s per plane]
# ExpId 2257606 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.638s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.750s | 0.450s per plane]
# ExpId 2257607 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.763s | 0.118s per plane]
# FFT timing for 15 DCR planes: [6.695s | 0.446s per plane]
# ExpId 2257608 Az: 180.0, ParAng: nan
# Selecting 10 obs from field 2585, with seeing range 0.679 to 1.223 and airmass range 1.132 to 1.177
# Number and flux contribution of stars of each type:
#  [M 68936| 1.57%] [K 10850| 1.94%] [G 6902| 3.70%] [F 2684| 4.66%] [A 516| 13.87%] [B 112| 74.26%] [O 0| 0.00%]
# Simulating 2517 stars within observable region
# Time to model 2507 stars: [12.452s | 0.00497s per star]
# Time to model 10 bright stars: [10.060s | 1.00598s per star]
# Simulating 243 quasars within observable region
# Time to model 243 stars: [2.478s | 0.01020s per star]
# Selecting 10 randomized obs from field 2585, with seeing range 0.545 to 0.880 and airmass range 1.016 to 1.544
# Writing 6448 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  4.8740708322414195 22.627302179467225
# FFT timing for 15 DCR planes: [1.586s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.659s | 0.444s per plane]
# ExpId 1258500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.593s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.636s | 0.442s per plane]
# ExpId 1258501 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.581s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.696s | 0.446s per plane]
# ExpId 1258502 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.597s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.683s | 0.446s per plane]
# ExpId 1258503 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.586s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.639s | 0.443s per plane]
# ExpId 1258504 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.578s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.626s | 0.442s per plane]
# ExpId 1258505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.594s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.687s | 0.446s per plane]
# ExpId 1258506 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.578s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.664s | 0.444s per plane]
# ExpId 1258507 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.612s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.661s | 0.444s per plane]
# ExpId 1258508 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.578s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.651s | 0.443s per plane]
# ExpId 1258509 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.567s | 0.104s per plane]
# FFT timing for 15 DCR planes: [6.616s | 0.441s per plane]
# ExpId 1258500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.591s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.701s | 0.447s per plane]
# ExpId 1258501 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.680s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.687s | 0.446s per plane]
# ExpId 1258502 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.571s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.685s | 0.446s per plane]
# ExpId 1258503 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.588s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.674s | 0.445s per plane]
# ExpId 1258504 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.593s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.613s | 0.441s per plane]
# ExpId 1258505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.630s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.624s | 0.442s per plane]
# ExpId 1258506 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.796s | 0.120s per plane]
# FFT timing for 15 DCR planes: [6.637s | 0.442s per plane]
# ExpId 1258507 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.946s | 0.130s per plane]
# FFT timing for 15 DCR planes: [6.629s | 0.442s per plane]
# ExpId 1258508 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.720s | 0.115s per plane]
# FFT timing for 15 DCR planes: [6.598s | 0.440s per plane]
# ExpId 1258509 Az: 0.0, ParAng: nan
# Selecting 9 randomized obs from field 2585, with seeing range 0.704 to 1.428 and airmass range 1.009 to 1.325
# FFT timing for 15 DCR planes: [1.578s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.629s | 0.442s per plane]
# ExpId 2258500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.581s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.652s | 0.443s per plane]
# ExpId 2258501 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.587s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.665s | 0.444s per plane]
# ExpId 2258502 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.601s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.670s | 0.445s per plane]
# ExpId 2258503 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.656s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.690s | 0.446s per plane]
# ExpId 2258504 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.602s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.646s | 0.443s per plane]
# ExpId 2258505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.606s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.679s | 0.445s per plane]
# ExpId 2258506 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.594s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.674s | 0.445s per plane]
# ExpId 2258507 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.608s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.676s | 0.445s per plane]
# ExpId 2258508 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.600s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.633s | 0.442s per plane]
# ExpId 2258500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.574s | 0.105s per plane]
# FFT timing for 15 DCR planes: [6.634s | 0.442s per plane]
# ExpId 2258501 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.597s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.652s | 0.443s per plane]
# ExpId 2258502 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.584s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.664s | 0.444s per plane]
# ExpId 2258503 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.602s | 0.107s per plane]
# FFT timing for 15 DCR planes: [7.862s | 0.524s per plane]
# ExpId 2258504 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.690s | 0.113s per plane]
# FFT timing for 15 DCR planes: [9.487s | 0.632s per plane]
# ExpId 2258505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.853s | 0.124s per plane]
# FFT timing for 15 DCR planes: [10.707s | 0.714s per plane]
# ExpId 2258506 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.128s | 0.142s per plane]
# FFT timing for 15 DCR planes: [9.578s | 0.639s per plane]
# ExpId 2258507 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.054s | 0.137s per plane]
# FFT timing for 15 DCR planes: [9.182s | 0.612s per plane]
# ExpId 2258508 Az: 0.0, ParAng: nan
# Selecting 12 obs from field 2733, with seeing range 0.544 to 0.893 and airmass range 1.172 to 1.257
# Number and flux contribution of stars of each type:
#  [M 68936| 1.57%] [K 10850| 1.94%] [G 6902| 3.70%] [F 2684| 4.66%] [A 516| 13.87%] [B 112| 74.26%] [O 0| 0.00%]
# Simulating 2579 stars within observable region
# Time to model 2574 stars: [13.476s | 0.00524s per star]
# Time to model 5 bright stars: [10.851s | 2.17027s per star]
# Simulating 219 quasars within observable region
# Time to model 218 stars: [3.203s | 0.01469s per star]
# Time to model 1 bright star: [7.932s]
# Selecting 12 randomized obs from field 2733, with seeing range 0.620 to 0.927 and airmass range 1.015 to 1.180
# Writing 6448 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  4.8740708322414195 22.627302179467225
# FFT timing for 15 DCR planes: [1.837s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.333s | 0.489s per plane]
# ExpId 1273300 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.730s | 0.115s per plane]
# FFT timing for 15 DCR planes: [8.074s | 0.538s per plane]
# ExpId 1273301 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.681s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.802s | 0.453s per plane]
# ExpId 1273302 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.630s | 0.109s per plane]
# FFT timing for 15 DCR planes: [8.276s | 0.552s per plane]
# ExpId 1273303 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.712s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.154s | 0.477s per plane]
# ExpId 1273304 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.744s | 0.116s per plane]
# FFT timing for 15 DCR planes: [7.106s | 0.474s per plane]
# ExpId 1273305 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.664s | 0.111s per plane]
# FFT timing for 15 DCR planes: [7.101s | 0.473s per plane]
# ExpId 1273306 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.633s | 0.109s per plane]
# FFT timing for 15 DCR planes: [9.231s | 0.615s per plane]
# ExpId 1273307 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.013s | 0.134s per plane]
# FFT timing for 15 DCR planes: [9.196s | 0.613s per plane]
# ExpId 1273308 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.750s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.526s | 0.502s per plane]
# ExpId 1273309 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.652s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.830s | 0.455s per plane]
# ExpId 1273310 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.627s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.774s | 0.452s per plane]
# ExpId 1273311 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.632s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.731s | 0.449s per plane]
# ExpId 1273300 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.643s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.957s | 0.464s per plane]
# ExpId 1273301 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.898s | 0.127s per plane]
# FFT timing for 15 DCR planes: [6.931s | 0.462s per plane]
# ExpId 1273302 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.679s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.767s | 0.451s per plane]
# ExpId 1273303 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.728s | 0.115s per plane]
# FFT timing for 15 DCR planes: [6.759s | 0.451s per plane]
# ExpId 1273304 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.609s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.842s | 0.456s per plane]
# ExpId 1273305 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.611s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.756s | 0.450s per plane]
# ExpId 1273306 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.618s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.738s | 0.449s per plane]
# ExpId 1273307 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.597s | 0.106s per plane]
# FFT timing for 15 DCR planes: [6.836s | 0.456s per plane]
# ExpId 1273308 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.614s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.889s | 0.459s per plane]
# ExpId 1273309 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.709s | 0.114s per plane]
# FFT timing for 15 DCR planes: [6.868s | 0.458s per plane]
# ExpId 1273310 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.917s | 0.128s per plane]
# FFT timing for 15 DCR planes: [7.315s | 0.488s per plane]
# ExpId 1273311 Az: 0.0, ParAng: nan
# Selecting 12 randomized obs from field 2733, with seeing range 0.687 to 1.440 and airmass range 1.016 to 1.297
# FFT timing for 15 DCR planes: [1.662s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.752s | 0.450s per plane]
# ExpId 2273300 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.649s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.727s | 0.448s per plane]
# ExpId 2273301 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.633s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.901s | 0.460s per plane]
# ExpId 2273302 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.661s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.951s | 0.463s per plane]
# ExpId 2273303 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.687s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.769s | 0.451s per plane]
# ExpId 2273304 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.679s | 0.112s per plane]
# FFT timing for 15 DCR planes: [6.883s | 0.459s per plane]
# ExpId 2273305 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.629s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.929s | 0.462s per plane]
# ExpId 2273306 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.619s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.785s | 0.452s per plane]
# ExpId 2273307 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.611s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.739s | 0.449s per plane]
# ExpId 2273308 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.618s | 0.108s per plane]
# FFT timing for 15 DCR planes: [7.200s | 0.480s per plane]
# ExpId 2273309 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.658s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.829s | 0.455s per plane]
# ExpId 2273310 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.613s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.745s | 0.450s per plane]
# ExpId 2273311 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.599s | 0.107s per plane]
# FFT timing for 15 DCR planes: [6.836s | 0.456s per plane]
# ExpId 2273300 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.609s | 0.107s per plane]
# FFT timing for 15 DCR planes: [7.768s | 0.518s per plane]
# ExpId 2273301 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.672s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.734s | 0.449s per plane]
# ExpId 2273302 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.625s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.830s | 0.455s per plane]
# ExpId 2273303 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.665s | 0.111s per plane]
# FFT timing for 15 DCR planes: [8.164s | 0.544s per plane]
# ExpId 2273304 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.070s | 0.138s per plane]
# FFT timing for 15 DCR planes: [8.902s | 0.593s per plane]
# ExpId 2273305 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.781s | 0.119s per plane]
# FFT timing for 15 DCR planes: [6.787s | 0.452s per plane]
# ExpId 2273306 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.608s | 0.107s per plane]
# FFT timing for 15 DCR planes: [7.361s | 0.491s per plane]
# ExpId 2273307 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.640s | 0.109s per plane]
# FFT timing for 15 DCR planes: [7.008s | 0.467s per plane]
# ExpId 2273308 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.758s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.939s | 0.529s per plane]
# ExpId 2273309 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.621s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.742s | 0.449s per plane]
# ExpId 2273310 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.607s | 0.107s per plane]
# FFT timing for 15 DCR planes: [8.388s | 0.559s per plane]
# ExpId 2273311 Az: 0.0, ParAng: nan
# Selecting 4 obs from field 2673, with seeing range 0.708 to 1.125 and airmass range 1.158 to 1.209
# Number and flux contribution of stars of each type:
#  [M 68936| 1.57%] [K 10850| 1.94%] [G 6902| 3.70%] [F 2684| 4.66%] [A 516| 13.87%] [B 112| 74.26%] [O 0| 0.00%]
# Simulating 2472 stars within observable region
# Time to model 2460 stars: [11.628s | 0.00473s per star]
# Time to model 12 bright stars: [14.731s | 1.22757s per star]
# Simulating 261 quasars within observable region
# Time to model 260 stars: [3.395s | 0.01306s per star]
# Time to model 1 bright star: [7.186s]
# Selecting 4 randomized obs from field 2673, with seeing range 0.567 to 1.175 and airmass range 1.064 to 1.590
# Writing 6448 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  4.8740708322414195 22.627302179467225
# FFT timing for 15 DCR planes: [2.116s | 0.141s per plane]
# FFT timing for 15 DCR planes: [8.344s | 0.556s per plane]
# ExpId 1267300 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.777s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.592s | 0.506s per plane]
# ExpId 1267301 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.742s | 0.116s per plane]
# FFT timing for 15 DCR planes: [6.958s | 0.464s per plane]
# ExpId 1267302 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.653s | 0.110s per plane]
# FFT timing for 15 DCR planes: [7.463s | 0.498s per plane]
# ExpId 1267303 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.855s | 0.124s per plane]
# FFT timing for 15 DCR planes: [7.142s | 0.476s per plane]
# ExpId 1267300 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [3.116s | 0.208s per plane]
# FFT timing for 15 DCR planes: [7.287s | 0.486s per plane]
# ExpId 1267301 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.863s | 0.124s per plane]
# FFT timing for 15 DCR planes: [7.668s | 0.511s per plane]
# ExpId 1267302 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.356s | 0.157s per plane]
# FFT timing for 15 DCR planes: [8.354s | 0.557s per plane]
# ExpId 1267303 Az: 180.0, ParAng: nan
# Selecting 7 randomized obs from field 2673, with seeing range 0.710 to 1.065 and airmass range 1.040 to 1.710
# FFT timing for 15 DCR planes: [1.648s | 0.110s per plane]
# FFT timing for 15 DCR planes: [7.390s | 0.493s per plane]
# ExpId 2267300 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.829s | 0.122s per plane]
# FFT timing for 15 DCR planes: [7.694s | 0.513s per plane]
# ExpId 2267301 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.800s | 0.120s per plane]
# FFT timing for 15 DCR planes: [7.055s | 0.470s per plane]
# ExpId 2267302 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.780s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.276s | 0.485s per plane]
# ExpId 2267303 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.927s | 0.128s per plane]
# FFT timing for 15 DCR planes: [7.513s | 0.501s per plane]
# ExpId 2267304 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.604s | 0.107s per plane]
# FFT timing for 15 DCR planes: [8.190s | 0.546s per plane]
# ExpId 2267305 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.877s | 0.125s per plane]
# FFT timing for 15 DCR planes: [7.966s | 0.531s per plane]
# ExpId 2267306 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.801s | 0.120s per plane]
# FFT timing for 15 DCR planes: [8.027s | 0.535s per plane]
# ExpId 2267300 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.939s | 0.129s per plane]
# FFT timing for 15 DCR planes: [7.369s | 0.491s per plane]
# ExpId 2267301 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.784s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.811s | 0.521s per plane]
# ExpId 2267302 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.783s | 0.119s per plane]
# FFT timing for 15 DCR planes: [7.222s | 0.481s per plane]
# ExpId 2267303 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.655s | 0.110s per plane]
# FFT timing for 15 DCR planes: [7.574s | 0.505s per plane]
# ExpId 2267304 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.652s | 0.110s per plane]
# FFT timing for 15 DCR planes: [7.564s | 0.504s per plane]
# ExpId 2267305 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.772s | 0.118s per plane]
# FFT timing for 15 DCR planes: [7.135s | 0.476s per plane]
# ExpId 2267306 Az: 180.0, ParAng: nan
# Selecting 10 obs from field 2775, with seeing range 0.690 to 1.160 and airmass range 1.206 to 1.255
# Number and flux contribution of stars of each type:
#  [M 68936| 1.57%] [K 10850| 1.94%] [G 6902| 3.70%] [F 2684| 4.66%] [A 516| 13.87%] [B 112| 74.26%] [O 0| 0.00%]
# Simulating 2513 stars within observable region
# Time to model 2504 stars: [12.335s | 0.00493s per star]
# Time to model 9 bright stars: [11.358s | 1.26198s per star]
# Simulating 249 quasars within observable region
# Time to model 248 stars: [3.357s | 0.01354s per star]
# Time to model 1 bright star: [8.141s]
# Selecting 10 randomized obs from field 2775, with seeing range 0.572 to 1.143 and airmass range 1.033 to 1.357
# Writing 6448 stars brighter than 16.0 mag to reference catalog in 1 bands
# Min/max magnitude:  4.8740708322414195 22.627302179467225
# FFT timing for 15 DCR planes: [1.944s | 0.130s per plane]
# FFT timing for 15 DCR planes: [7.338s | 0.489s per plane]
# ExpId 1277500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.861s | 0.124s per plane]
# FFT timing for 15 DCR planes: [7.662s | 0.511s per plane]
# ExpId 1277501 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.662s | 0.111s per plane]
# FFT timing for 15 DCR planes: [6.990s | 0.466s per plane]
# ExpId 1277502 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.643s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.861s | 0.457s per plane]
# ExpId 1277503 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.643s | 0.110s per plane]
# FFT timing for 15 DCR planes: [6.858s | 0.457s per plane]
# ExpId 1277504 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.626s | 0.108s per plane]
# FFT timing for 15 DCR planes: [6.830s | 0.455s per plane]
# ExpId 1277505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.632s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.886s | 0.459s per plane]
# ExpId 1277506 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.642s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.830s | 0.455s per plane]
# ExpId 1277507 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.644s | 0.110s per plane]
# FFT timing for 15 DCR planes: [9.532s | 0.635s per plane]
# ExpId 1277508 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.835s | 0.122s per plane]
# FFT timing for 15 DCR planes: [9.264s | 0.618s per plane]
# ExpId 1277509 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.261s | 0.151s per plane]
# FFT timing for 15 DCR planes: [8.726s | 0.582s per plane]
# ExpId 1277500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.501s | 0.167s per plane]
# FFT timing for 15 DCR planes: [8.294s | 0.553s per plane]
# ExpId 1277501 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.668s | 0.111s per plane]
# FFT timing for 15 DCR planes: [8.338s | 0.556s per plane]
# ExpId 1277502 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.226s | 0.148s per plane]
# FFT timing for 15 DCR planes: [8.339s | 0.556s per plane]
# ExpId 1277503 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.255s | 0.150s per plane]
# FFT timing for 15 DCR planes: [10.733s | 0.716s per plane]
# ExpId 1277504 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.477s | 0.165s per plane]
# FFT timing for 15 DCR planes: [10.086s | 0.672s per plane]
# ExpId 1277505 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.013s | 0.134s per plane]
# FFT timing for 15 DCR planes: [8.958s | 0.597s per plane]
# ExpId 1277506 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.344s | 0.156s per plane]
# FFT timing for 15 DCR planes: [10.096s | 0.673s per plane]
# ExpId 1277507 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.139s | 0.143s per plane]
# FFT timing for 15 DCR planes: [8.548s | 0.570s per plane]
# ExpId 1277508 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.640s | 0.109s per plane]
# FFT timing for 15 DCR planes: [7.067s | 0.471s per plane]
# ExpId 1277509 Az: 180.0, ParAng: nan
# Selecting 5 randomized obs from field 2775, with seeing range 0.655 to 0.985 and airmass range 1.026 to 1.109
# FFT timing for 15 DCR planes: [1.630s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.766s | 0.451s per plane]
# ExpId 2277500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.705s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.808s | 0.521s per plane]
# ExpId 2277501 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [2.478s | 0.165s per plane]
# FFT timing for 15 DCR planes: [7.272s | 0.485s per plane]
# ExpId 2277502 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.695s | 0.113s per plane]
# FFT timing for 15 DCR planes: [6.910s | 0.461s per plane]
# ExpId 2277503 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.630s | 0.109s per plane]
# FFT timing for 15 DCR planes: [6.944s | 0.463s per plane]
# ExpId 2277504 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.752s | 0.117s per plane]
# FFT timing for 15 DCR planes: [7.148s | 0.477s per plane]
# ExpId 2277500 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.990s | 0.133s per plane]
# FFT timing for 15 DCR planes: [8.407s | 0.560s per plane]
# ExpId 2277501 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.931s | 0.129s per plane]
# FFT timing for 15 DCR planes: [7.413s | 0.494s per plane]
# ExpId 2277502 Az: 0.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.716s | 0.114s per plane]
# FFT timing for 15 DCR planes: [7.587s | 0.506s per plane]
# ExpId 2277503 Az: 180.0, ParAng: nan
# FFT timing for 15 DCR planes: [1.887s | 0.126s per plane]
# FFT timing for 15 DCR planes: [8.083s | 0.539s per plane]
# ExpId 2277504 Az: 180.0, ParAng: nan

# %% [markdown]
# lsst::geom::Angle VisitInfo::getLocalEra() const { return getEra() + getObservatory().getLongitude(); }
#
# lsst::geom::Angle VisitInfo::getBoresightHourAngle() const { return getLocalEra() - getBoresightRaDec()[0]; }
#
# lsst::geom::Angle VisitInfo::getBoresightParAngle() const {
#     /**
#      * Compute the parallactic angle.
#      * Defined as the angle between the North celestial pole and Zenith at the boresight.
#      */
#     double _parallactic_y, _parallactic_x, result;
#     _parallactic_y = sin(getBoresightHourAngle().asRadians());
#     _parallactic_x =
#             cos((getBoresightRaDec()[1]).asRadians()) * tan(getObservatory().getLatitude().asRadians()) -
#             sin((getBoresightRaDec()[1]).asRadians()) * cos(getBoresightHourAngle().asRadians());
#     result = atan2(_parallactic_y, _parallactic_x);
#     return result * lsst::geom::radians;
# }

# %% [markdown]
# Make a text file containing the visit list

# %%
visits = None
mosaic = True
randomize_conditions = True
band_dict = {'u': 0, 'g': 1, 'r': 2, 'i': 3, 'z': 4, 'y': 5}
seeing_dict = {}
airmass_dict = {}
for d_y, n_obs in zip(dither_y, n_obs_list):
    rng = np.random.RandomState(n_obs + 2)
    for rpt in range(repeat_obs):
        d_x = dither_x[rpt]
        index = int(np.rint(rng.rand()*1000))
        opsim.set_field(n_obs=n_obs, index=index, year=template_year)
        if randomize_template:
            opsim.update_year(template_year, randomize_conditions=randomize_conditions)
        n_obs1 = len(opsim.airmass)
        for t_i in range(n_obs1):
            fieldId_i = 100*opsim.field_Id + 1000000*template_year + t_i
            seeing_dict[fieldId_i] = opsim.seeing[t_i]
            airmass_dict[fieldId_i] = opsim.airmass[t_i]
        opsim.update_year(alert_year, randomize_conditions=randomize_conditions)
        n_obs2 = len(opsim.airmass)
        if mosaic:
            visit_name1 = "%i" % (100*opsim.field_Id + 1000000*template_year)
            visit_name1b = "%i" % (100*opsim.field_Id + 1000000*template_year + n_obs1 - 1)
            visit_name2 = "%i" % (100*opsim.field_Id + 1000000*alert_year)
            visit_name2b = "%i" % (100*opsim.field_Id + 1000000*alert_year + n_obs2 - 1)
        else:
            visit_name1 = "%i" % (100*band_dict[opsim.filter] + 1000*template_year)
            visit_name1b = "%i" % (100*band_dict[opsim.filter] + 1000*template_year + n_obs1 - 1)
            visit_name2 = "%i" % (100*band_dict[opsim.filter] + 1000*alert_year)
            visit_name2b = "%i" % (100*band_dict[opsim.filter] + 1000*alert_year + n_obs2 - 1)
        if visits is None:
            visits = visit_name1
        else:
            visits += "^" + visit_name1
        visits += "..%s^%s..%s" % (visit_name1b, visit_name2, visit_name2b)
# Out:
# Selecting 10 obs from field 2682, with seeing range 0.541 to 0.815 and airmass range 1.158 to 1.209
# Selecting 10 randomized obs from field 2682, with seeing range 0.504 to 1.019 and airmass range 1.021 to 1.509
# Selecting 7 randomized obs from field 2682, with seeing range 0.675 to 1.210 and airmass range 1.007 to 1.207
# Selecting 8 obs from field 2725, with seeing range 0.699 to 1.011 and airmass range 1.167 to 1.250
# Selecting 8 randomized obs from field 2725, with seeing range 0.527 to 1.374 and airmass range 1.025 to 1.292
# Selecting 13 randomized obs from field 2725, with seeing range 0.523 to 0.956 and airmass range 1.024 to 1.156
# Selecting 6 obs from field 2874, with seeing range 0.575 to 0.759 and airmass range 1.204 to 1.271
# Selecting 6 randomized obs from field 2874, with seeing range 0.542 to 0.781 and airmass range 1.034 to 1.247
# Selecting 3 randomized obs from field 2874, with seeing range 0.745 to 1.422 and airmass range 1.034 to 1.879
# Selecting 12 obs from field 359, with seeing range 0.564 to 1.414 and airmass range 1.148 to 1.190
# Selecting 12 randomized obs from field 359, with seeing range 0.702 to 1.162 and airmass range 1.030 to 2.025
# Selecting 12 randomized obs from field 359, with seeing range 0.694 to 0.984 and airmass range 1.010 to 1.195
# Selecting 10 obs from field 2576, with seeing range 0.619 to 1.106 and airmass range 1.119 to 1.200
# Selecting 10 randomized obs from field 2576, with seeing range 0.533 to 1.586 and airmass range 1.029 to 1.685
# Selecting 9 randomized obs from field 2576, with seeing range 0.529 to 1.064 and airmass range 1.016 to 1.509
# Selecting 10 obs from field 2585, with seeing range 0.679 to 1.223 and airmass range 1.132 to 1.177
# Selecting 10 randomized obs from field 2585, with seeing range 0.545 to 0.880 and airmass range 1.016 to 1.544
# Selecting 9 randomized obs from field 2585, with seeing range 0.704 to 1.428 and airmass range 1.009 to 1.325
# Selecting 12 obs from field 2733, with seeing range 0.544 to 0.893 and airmass range 1.172 to 1.257
# Selecting 12 randomized obs from field 2733, with seeing range 0.620 to 0.927 and airmass range 1.015 to 1.180
# Selecting 12 randomized obs from field 2733, with seeing range 0.687 to 1.440 and airmass range 1.016 to 1.297
# Selecting 4 obs from field 2673, with seeing range 0.708 to 1.125 and airmass range 1.158 to 1.209
# Selecting 4 randomized obs from field 2673, with seeing range 0.567 to 1.175 and airmass range 1.064 to 1.590
# Selecting 7 randomized obs from field 2673, with seeing range 0.710 to 1.065 and airmass range 1.040 to 1.710
# Selecting 10 obs from field 2775, with seeing range 0.690 to 1.160 and airmass range 1.206 to 1.255
# Selecting 10 randomized obs from field 2775, with seeing range 0.572 to 1.143 and airmass range 1.033 to 1.357
# Selecting 5 randomized obs from field 2775, with seeing range 0.655 to 0.985 and airmass range 1.026 to 1.109

# %%
print(visits)
# Out:
# 1268200..1268209^2268200..2268206^1272500..1272507^2272500..2272512^1287400..1287405^2287400..2287402^1035900..1035911^2035900..2035911^1257600..1257609^2257600..2257608^1258500..1258509^2258500..2258508^1273300..1273311^2273300..2273311^1267300..1267303^2267300..2267306^1277500..1277509^2277500..2277504

# %%
use_seeing = False
output_directory = opsim.sim_directory + "mosaic_%i_constPSF_rand/" % opsim.seed
visits_file = output_directory + "visits.txt"
visits_cmd = "--id visit=" + visits
np.savetxt(visits_file, [visits_cmd], fmt='%s')

# %%
visits_cmd
# Out:
# '--id visit=1268200..1268209^2268200..2268206^1272500..1272507^2272500..2272512^1287400..1287405^2287400..2287402^1035900..1035911^2035900..2035911^1257600..1257609^2257600..2257608^1258500..1258509^2258500..2258508^1273300..1273311^2273300..2273311^1267300..1267303^2267300..2267306^1277500..1277509^2277500..2277504'

# %%
opsim.seeing
